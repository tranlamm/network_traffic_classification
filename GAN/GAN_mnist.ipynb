# %%
# Load dữ liệu mnist
from keras.datasets.mnist import load_data
import numpy as np
(trainX, trainy), (testX, testy) = load_data()
print('Train', trainX.shape, trainy.shape)
print('Test', testX.shape, testy.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step
# Train (60000, 28, 28) (60000,)
# Test (10000, 28, 28) (10000,)

# %%
idx = np.where(trainy.flatten() <= 3)
trainX = trainX[idx]

# %%
idx = np.where(testy.flatten() <= 3)
know = testX[idx]
know_label = np.ones((know.shape[0], 1))

idx = np.where(testy.flatten() >= 7)
unknow = testX[idx]
unknow_label = np.zeros((unknow.shape[0], 1))

# %%
print(know.shape, know_label.shape)
print(unknow.shape, unknow_label.shape)
# Out:
# (4157, 28, 28) (4157, 1)
# (3011, 28, 28) (3011, 1)

# %%
eval_x = np.concatenate((know, unknow))
eval_y = np.concatenate((know_label, unknow_label))

# %%
idx = np.random.permutation(eval_x.shape[0])
eval_x = eval_x[idx]
eval_y = eval_y[idx]

# %%
print(eval_x.shape, eval_y.shape)
# Out:
# (7168, 28, 28) (7168, 1)

# %%
import matplotlib.pyplot as plt

# plot images from the training dataset
def _plot(X):
	for i in range(25):
		# define subplot
		plt.subplot(5, 5, 1 + i)
		# turn off axis
		plt.axis('off')
		# plot raw pixel data
		plt.imshow(X[i], cmap='gray_r')
	plt.show()

_plot(trainX[:25, :])

# %%
from keras.layers import Input, Conv2D, Flatten, LeakyReLU, Dropout, Dense, Reshape
from keras.models import Model
from keras.optimizers import Adam
from keras.utils import plot_model

def _discriminator():
  # Khai báo các layers
  inpt = Input(shape=(28, 28, 1))
  conv1 = Conv2D(filters=32, kernel_size=(3,3), strides=(2,2), padding='same')(inpt)
  act_leak1 = LeakyReLU(alpha=0.3)(conv1)
  dropout = Dropout(0.4)(act_leak1)
  conv2 = Conv2D(filters=64, kernel_size=(3,3), strides=(2,2), padding='same')(dropout)
  act_leak2 = LeakyReLU(alpha=0.3)(conv2)
  flat = Flatten()(act_leak2)
  den = Dense(1, activation='sigmoid')(flat)
  # Khởi tạo model
  model = Model(inputs = [inpt], outputs = [den])
  # Compile với optimizer
  opt = Adam(learning_rate=0.0002, beta_1=0.5)
  model.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])
  return model

discriminator = _discriminator()
plot_model(discriminator, show_shapes=True)

# %%
from keras.layers import Conv2DTranspose

def _generator(noise_size = 100):
  n_units = 64*7*7
  inpt = Input(shape=(noise_size))
  den1 = Dense(n_units)(inpt)
  act_leak1 = LeakyReLU(alpha=0.3)(den1)
  reshape = Reshape((7,7,64))(act_leak1)
  con2DTran1 = Conv2DTranspose(64, kernel_size=(3,3), strides=(2,2), padding='same')(reshape)
  act_leak2 = LeakyReLU(alpha=0.3)(con2DTran1)
  con2DTran2 = Conv2DTranspose(32, kernel_size=(3,3), strides=(2,2), padding='same')(act_leak2)
  act_leak3 = LeakyReLU(alpha=0.3)(con2DTran2)
  con = Conv2D(filters=1, kernel_size=(28, 28), activation='sigmoid', padding='same')(act_leak3)

  # Khởi tạo model
  model = Model(inputs = [inpt], outputs = [con])
  # Compile với optimizer
  opt = Adam(learning_rate=0.0002, beta_1=0.5)
  model.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])
  return model

generator = _generator(noise_size = 128)
plot_model(generator, show_shapes=True)

# %%
from keras.models import Sequential

def _gan(g_model, d_model):
  # Đóng băng weight của discriminator
	d_model.trainable = False
	# Khởi tạo model GAN
	model = Sequential()
	model.add(g_model)
	model.add(d_model)
	# compile model
	opt = Adam(learning_rate=0.005, beta_1=0.5)
	model.compile(loss='binary_crossentropy', optimizer=opt)
	return model

# Khai báo số chiều của noise véc tơ input của generator.
latent_dim = 128
# Khởi tạo discriminator và generatator model
d_model = _discriminator()
g_model = _generator(latent_dim)
# Khởi tạo GAN model
gan_model = _gan(g_model, d_model)
plot_model(gan_model, show_shapes=True)

# %%
def _normalize():
	# load mnist dataset
	(trainX, _), (_, _) = load_data()
	X = np.expand_dims(trainX, axis=-1)
	X = X.astype('float32')
	X = X / 255.0
	return X

# %%
import numpy as np

# Hàm sinh batch input là noise véc tơ cho generator
def generate_latent_points(latent_dim, n_samples):
	# khởi tạo input ngẫu nhiên
	x_input = np.random.randn(latent_dim * n_samples)
	# reshape về batch
	x_input = x_input.reshape(n_samples, latent_dim)
	return x_input


# Hàm sinh batch cho fake sample, nhãn của fake sample là 0
def generate_fake_samples(g_model, latent_dim, n_samples):
	# sinh batch là các noise véc tơ
	x_input = generate_latent_points(latent_dim, n_samples)
	# dự báo outputs từ g_model
	X = g_model.predict(x_input)
	# khởi tạo y = 0 với nhãn fake
	y = np.zeros((n_samples, 1))
	return X, y

# %%
def generate_real_samples(dataset, n_samples):
	# lựa chọn index ngẫu nhiên để lựa chọn batch
	ix = np.random.randint(0, dataset.shape[0], n_samples)
	# trích suất các ảnh từ dataset
	X = dataset[ix]
	# khởi tạo y = 1 với nhãn real
	y = np.ones((n_samples, 1))
	return X, y

# %%
# đánh giá accuracy của discriminator trên cả tập real và tập fake
def summarize_performance(epoch, gan_model, X_real, y_real, X_fake, y_fake):
	_, acc_real = gan_model.layers[1].evaluate(X_real, y_real, verbose=0)
	_, acc_fake = gan_model.layers[1].evaluate(X_fake, y_fake, verbose=0)
	# thống kê discriminator performance
	print('>Accuracy real: %.0f%%, fake: %.0f%%' % (acc_real*100, acc_fake*100))

# %%
def train(g_model, d_model, gan_model, dataset, latent_dim, n_epochs=50, n_batch=256, k=2):
  bat_per_epo = int(dataset.shape[0] / n_batch)
  half_batch = int(n_batch / 2)
  # Huấn luyện mô hình trên các epochs
  for i in range(n_epochs):
    for j in range(bat_per_epo):
      if j % k == 0:
        # Step 1: Huấn luyện trên discriminator
        gan_model.layers[0].trainable = False
        gan_model.layers[1].trainable = True
        # Khởi tạo batch huấn luyện trong đó có 1/2 batch là real và 1/2 batch là fake
        X_real, y_real = generate_real_samples(dataset, half_batch)
        X_fake, y_fake = generate_fake_samples(gan_model.layers[0], latent_dim, half_batch)
        X, y = np.vstack((X_real, X_fake)), np.vstack((y_real, y_fake))
        d_loss, _ = gan_model.layers[1].train_on_batch(X, y)
        print('>%d, %d/%d, d=%.3f' % (i+1, j+1, bat_per_epo, d_loss))

      # Step 2: Huấn luyện trên generator
      # Khởi tạo batch noise
      X_gan = generate_latent_points(latent_dim, n_batch)
      # Những dữ liệu noise này giả định là đã đánh lừa được discriminator nên được gán nhãn là 1
      y_gan = np.ones((n_batch, 1))
      # huấn luyện generator thông qua gan_model
      gan_model.layers[0].trainable = True
      gan_model.layers[1].trainable = False
      g_loss = gan_model.train_on_batch(X_gan, y_gan)
      # Loss function trên discriminator, generator
      print('>%d, %d/%d, d=%.3f, g=%.3f' % (i+1, j+1, bat_per_epo, d_loss, g_loss))
      # Đánh giá mô hình:
      summarize_performance(j, gan_model, X_real, y_real, X_fake, y_fake)

# %%
# train model
dataset = _normalize()
train(g_model, d_model, gan_model, dataset, latent_dim, n_epochs=100, n_batch=128)
# Out:
# Streaming output truncated to the last 5000 lines.
# >Accuracy real: 100%, fake: 100%
# >32, 194/468, d=0.025, g=14.456
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 8ms/step
# >32, 195/468, d=0.009
# >32, 195/468, d=0.009, g=14.836
# >Accuracy real: 100%, fake: 100%
# >32, 196/468, d=0.009, g=15.064
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 7ms/step
# >32, 197/468, d=0.010
# >32, 197/468, d=0.010, g=14.405
# >Accuracy real: 100%, fake: 100%
# >32, 198/468, d=0.010, g=13.810
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 6ms/step
# >32, 199/468, d=0.007
# >32, 199/468, d=0.007, g=12.980
# >Accuracy real: 100%, fake: 100%
# >32, 200/468, d=0.007, g=14.273
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 18ms/step
# >32, 201/468, d=0.006
# >32, 201/468, d=0.006, g=13.381
# >Accuracy real: 100%, fake: 100%
# >32, 202/468, d=0.006, g=13.899
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 9ms/step
# >32, 203/468, d=0.018
# >32, 203/468, d=0.018, g=12.515
# >Accuracy real: 100%, fake: 100%
# >32, 204/468, d=0.018, g=13.471
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 8ms/step
# >32, 205/468, d=0.014
# >32, 205/468, d=0.014, g=14.297
# >Accuracy real: 100%, fake: 100%
# >32, 206/468, d=0.014, g=13.788
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 6ms/step
# >32, 207/468, d=0.006
# >32, 207/468, d=0.006, g=12.615
# >Accuracy real: 100%, fake: 100%
# >32, 208/468, d=0.006, g=13.139
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 9ms/step
# >32, 209/468, d=0.016
# >32, 209/468, d=0.016, g=13.593
# >Accuracy real: 100%, fake: 100%
# >32, 210/468, d=0.016, g=14.279
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 6ms/step
# >32, 211/468, d=0.002
# >32, 211/468, d=0.002, g=13.845
# >Accuracy real: 100%, fake: 100%
# >32, 212/468, d=0.002, g=13.068
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 7ms/step
# >32, 213/468, d=0.001
# >32, 213/468, d=0.001, g=12.703
# >Accuracy real: 100%, fake: 100%
# >32, 214/468, d=0.001, g=12.975
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 10ms/step
# >32, 215/468, d=0.002
# >32, 215/468, d=0.002, g=12.754
# >Accuracy real: 100%, fake: 100%
# >32, 216/468, d=0.002, g=13.093
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 13ms/step
# >32, 217/468, d=0.006
# >32, 217/468, d=0.006, g=13.323
# >Accuracy real: 100%, fake: 100%
# >32, 218/468, d=0.006, g=12.846
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 7ms/step
# >32, 219/468, d=0.003
# >32, 219/468, d=0.003, g=13.655
# >Accuracy real: 100%, fake: 100%
# >32, 220/468, d=0.003, g=13.451
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 15ms/step
# >32, 221/468, d=0.009
# >32, 221/468, d=0.009, g=13.988
# >Accuracy real: 100%, fake: 100%
# >32, 222/468, d=0.009, g=13.201
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 14ms/step
# >32, 223/468, d=0.002
# >32, 223/468, d=0.002, g=14.215
# >Accuracy real: 100%, fake: 100%
# >32, 224/468, d=0.002, g=13.545
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 14ms/step
# >32, 225/468, d=0.005
# >32, 225/468, d=0.005, g=14.331
# >Accuracy real: 100%, fake: 100%
# >32, 226/468, d=0.005, g=12.730
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 7ms/step
# >32, 227/468, d=0.003
# >32, 227/468, d=0.003, g=12.754
# >Accuracy real: 100%, fake: 100%
# >32, 228/468, d=0.003, g=13.744
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 10ms/step
# >32, 229/468, d=0.004
# >32, 229/468, d=0.004, g=12.967
# >Accuracy real: 100%, fake: 100%
# >32, 230/468, d=0.004, g=13.008
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 7ms/step
# >32, 231/468, d=0.015
# >32, 231/468, d=0.015, g=13.808
# >Accuracy real: 100%, fake: 100%
# >32, 232/468, d=0.015, g=13.767
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 12ms/step
# >32, 233/468, d=0.009
# >32, 233/468, d=0.009, g=13.850
# >Accuracy real: 100%, fake: 100%
# >32, 234/468, d=0.009, g=12.932
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 6ms/step
# >32, 235/468, d=0.004
# >32, 235/468, d=0.004, g=14.164
# >Accuracy real: 100%, fake: 100%
# >32, 236/468, d=0.004, g=14.631
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 10ms/step
# >32, 237/468, d=0.005
# >32, 237/468, d=0.005, g=13.934
# >Accuracy real: 100%, fake: 100%
# >32, 238/468, d=0.005, g=14.320
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 6ms/step
# >32, 239/468, d=0.008
# >32, 239/468, d=0.008, g=14.298
# >Accuracy real: 100%, fake: 100%
# >32, 240/468, d=0.008, g=13.711
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 10ms/step
# >32, 241/468, d=0.006
# >32, 241/468, d=0.006, g=13.727
# >Accuracy real: 100%, fake: 100%
# >32, 242/468, d=0.006, g=14.167
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 6ms/step
# >32, 243/468, d=0.004
# >32, 243/468, d=0.004, g=13.730
# >Accuracy real: 100%, fake: 100%
# >32, 244/468, d=0.004, g=13.771
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 7ms/step
# >32, 245/468, d=0.002
# >32, 245/468, d=0.002, g=12.968
# >Accuracy real: 100%, fake: 100%
# >32, 246/468, d=0.002, g=12.986
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 7ms/step
# >32, 247/468, d=0.015
# >32, 247/468, d=0.015, g=12.578
# >Accuracy real: 100%, fake: 100%
# >32, 248/468, d=0.015, g=12.605
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 16ms/step
# >32, 249/468, d=0.015
# >32, 249/468, d=0.015, g=12.931
# >Accuracy real: 100%, fake: 100%
# >32, 250/468, d=0.015, g=13.927
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 10ms/step
# >32, 251/468, d=0.008
# >32, 251/468, d=0.008, g=12.281
# >Accuracy real: 100%, fake: 100%
# >32, 252/468, d=0.008, g=15.120
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 6ms/step
# >32, 253/468, d=0.006
# >32, 253/468, d=0.006, g=13.635
# >Accuracy real: 100%, fake: 100%
# >32, 254/468, d=0.006, g=12.744
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 12ms/step
# >32, 255/468, d=0.011
# >32, 255/468, d=0.011, g=13.146
# >Accuracy real: 100%, fake: 100%
# >32, 256/468, d=0.011, g=14.168
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 18ms/step
# >32, 257/468, d=0.003
# >32, 257/468, d=0.003, g=13.764
# >Accuracy real: 100%, fake: 100%
# >32, 258/468, d=0.003, g=13.404
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 7ms/step
# >32, 259/468, d=0.012
# >32, 259/468, d=0.012, g=14.490
# >Accuracy real: 100%, fake: 98%
# >32, 260/468, d=0.012, g=14.885
# >Accuracy real: 100%, fake: 98%
# 2/2 [==============================] - 0s 15ms/step
# >32, 261/468, d=0.001
# >32, 261/468, d=0.001, g=15.053
# >Accuracy real: 100%, fake: 100%
# >32, 262/468, d=0.001, g=14.933
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 6ms/step
# >32, 263/468, d=0.007
# >32, 263/468, d=0.007, g=14.022
# >Accuracy real: 100%, fake: 100%
# >32, 264/468, d=0.007, g=14.140
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 7ms/step
# >32, 265/468, d=0.006
# >32, 265/468, d=0.006, g=14.490
# >Accuracy real: 100%, fake: 100%
# >32, 266/468, d=0.006, g=14.391
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 12ms/step
# >32, 267/468, d=0.064
# >32, 267/468, d=0.064, g=12.580
# >Accuracy real: 97%, fake: 100%
# >32, 268/468, d=0.064, g=13.344
# >Accuracy real: 97%, fake: 100%
# 2/2 [==============================] - 0s 12ms/step
# >32, 269/468, d=0.002
# >32, 269/468, d=0.002, g=12.541
# >Accuracy real: 100%, fake: 100%
# >32, 270/468, d=0.002, g=12.543
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 7ms/step
# >32, 271/468, d=0.002
# >32, 271/468, d=0.002, g=11.047
# >Accuracy real: 100%, fake: 100%
# >32, 272/468, d=0.002, g=13.233
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 7ms/step
# >32, 273/468, d=0.004
# >32, 273/468, d=0.004, g=11.549
# >Accuracy real: 100%, fake: 100%
# >32, 274/468, d=0.004, g=12.098
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 16ms/step
# >32, 275/468, d=0.027
# >32, 275/468, d=0.027, g=13.313
# >Accuracy real: 100%, fake: 100%
# >32, 276/468, d=0.027, g=13.386
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 8ms/step
# >32, 277/468, d=0.003
# >32, 277/468, d=0.003, g=13.617
# >Accuracy real: 100%, fake: 100%
# >32, 278/468, d=0.003, g=13.333
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 11ms/step
# >32, 279/468, d=0.006
# >32, 279/468, d=0.006, g=13.440
# >Accuracy real: 100%, fake: 100%
# >32, 280/468, d=0.006, g=13.869
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 12ms/step
# >32, 281/468, d=0.012
# >32, 281/468, d=0.012, g=12.753
# >Accuracy real: 100%, fake: 100%
# >32, 282/468, d=0.012, g=13.205
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 6ms/step
# >32, 283/468, d=0.010
# >32, 283/468, d=0.010, g=12.346
# >Accuracy real: 100%, fake: 100%
# >32, 284/468, d=0.010, g=14.035
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 18ms/step
# >32, 285/468, d=0.006
# >32, 285/468, d=0.006, g=13.875
# >Accuracy real: 100%, fake: 100%
# >32, 286/468, d=0.006, g=13.688
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 15ms/step
# >32, 287/468, d=0.002
# >32, 287/468, d=0.002, g=14.842
# >Accuracy real: 100%, fake: 100%
# >32, 288/468, d=0.002, g=13.632
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 6ms/step
# >32, 289/468, d=0.008
# >32, 289/468, d=0.008, g=14.516
# >Accuracy real: 100%, fake: 100%
# >32, 290/468, d=0.008, g=14.490
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 11ms/step
# >32, 291/468, d=0.013
# >32, 291/468, d=0.013, g=13.675
# >Accuracy real: 100%, fake: 100%
# >32, 292/468, d=0.013, g=13.767
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 7ms/step
# >32, 293/468, d=0.002
# >32, 293/468, d=0.002, g=14.851
# >Accuracy real: 100%, fake: 100%
# >32, 294/468, d=0.002, g=13.607
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 7ms/step
# >32, 295/468, d=0.001
# >32, 295/468, d=0.001, g=13.795
# >Accuracy real: 100%, fake: 100%
# >32, 296/468, d=0.001, g=13.753
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 6ms/step
# >32, 297/468, d=0.004
# >32, 297/468, d=0.004, g=14.134
# >Accuracy real: 100%, fake: 100%
# >32, 298/468, d=0.004, g=14.358
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 7ms/step
# >32, 299/468, d=0.006
# >32, 299/468, d=0.006, g=15.539
# >Accuracy real: 100%, fake: 100%
# >32, 300/468, d=0.006, g=14.651
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 7ms/step
# >32, 301/468, d=0.007
# >32, 301/468, d=0.007, g=13.997
# >Accuracy real: 100%, fake: 100%
# >32, 302/468, d=0.007, g=13.734
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 7ms/step
# >32, 303/468, d=0.031
# >32, 303/468, d=0.031, g=14.868
# >Accuracy real: 100%, fake: 100%
# >32, 304/468, d=0.031, g=13.865
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 12ms/step
# >32, 305/468, d=0.002
# >32, 305/468, d=0.002, g=14.279
# >Accuracy real: 100%, fake: 100%
# >32, 306/468, d=0.002, g=14.433
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 11ms/step
# >32, 307/468, d=0.006
# >32, 307/468, d=0.006, g=15.093
# >Accuracy real: 100%, fake: 100%
# >32, 308/468, d=0.006, g=14.048
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 17ms/step
# >32, 309/468, d=0.018
# >32, 309/468, d=0.018, g=13.947
# >Accuracy real: 98%, fake: 100%
# >32, 310/468, d=0.018, g=12.622
# >Accuracy real: 98%, fake: 100%
# 2/2 [==============================] - 0s 13ms/step
# >32, 311/468, d=0.008
# >32, 311/468, d=0.008, g=14.063
# >Accuracy real: 100%, fake: 100%
# >32, 312/468, d=0.008, g=14.360
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 6ms/step
# >32, 313/468, d=0.001
# >32, 313/468, d=0.001, g=13.898
# >Accuracy real: 100%, fake: 100%
# >32, 314/468, d=0.001, g=14.438
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 14ms/step
# >32, 315/468, d=0.001
# >32, 315/468, d=0.001, g=14.278
# >Accuracy real: 100%, fake: 100%
# >32, 316/468, d=0.001, g=13.273
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 9ms/step
# >32, 317/468, d=0.004
# >32, 317/468, d=0.004, g=14.835
# >Accuracy real: 100%, fake: 100%
# >32, 318/468, d=0.004, g=14.136
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 7ms/step
# >32, 319/468, d=0.008
# >32, 319/468, d=0.008, g=14.533
# >Accuracy real: 100%, fake: 100%
# >32, 320/468, d=0.008, g=15.226
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 10ms/step
# >32, 321/468, d=0.003
# >32, 321/468, d=0.003, g=14.097
# >Accuracy real: 100%, fake: 100%
# >32, 322/468, d=0.003, g=14.472
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 7ms/step
# >32, 323/468, d=0.001
# >32, 323/468, d=0.001, g=13.965
# >Accuracy real: 100%, fake: 100%
# >32, 324/468, d=0.001, g=15.227
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 6ms/step
# >32, 325/468, d=0.001
# >32, 325/468, d=0.001, g=14.360
# >Accuracy real: 100%, fake: 100%
# >32, 326/468, d=0.001, g=14.799
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 9ms/step
# >32, 327/468, d=0.009
# >32, 327/468, d=0.009, g=14.783
# >Accuracy real: 100%, fake: 100%
# >32, 328/468, d=0.009, g=14.563
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 6ms/step
# >32, 329/468, d=0.002
# >32, 329/468, d=0.002, g=13.303
# >Accuracy real: 100%, fake: 100%
# >32, 330/468, d=0.002, g=14.519
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 11ms/step
# >32, 331/468, d=0.007
# >32, 331/468, d=0.007, g=14.535
# >Accuracy real: 100%, fake: 100%
# >32, 332/468, d=0.007, g=14.359
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 11ms/step
# >32, 333/468, d=0.010
# >32, 333/468, d=0.010, g=14.866
# >Accuracy real: 100%, fake: 98%
# >32, 334/468, d=0.010, g=14.422
# >Accuracy real: 100%, fake: 98%
# 2/2 [==============================] - 0s 6ms/step
# >32, 335/468, d=0.004
# >32, 335/468, d=0.004, g=14.847
# >Accuracy real: 100%, fake: 100%
# >32, 336/468, d=0.004, g=13.839
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 9ms/step
# >32, 337/468, d=0.006
# >32, 337/468, d=0.006, g=14.083
# >Accuracy real: 100%, fake: 100%
# >32, 338/468, d=0.006, g=14.331
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 7ms/step
# >32, 339/468, d=0.003
# >32, 339/468, d=0.003, g=13.684
# >Accuracy real: 100%, fake: 100%
# >32, 340/468, d=0.003, g=13.885
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 11ms/step
# >32, 341/468, d=0.005
# >32, 341/468, d=0.005, g=14.181
# >Accuracy real: 100%, fake: 100%
# >32, 342/468, d=0.005, g=14.505
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 9ms/step
# >32, 343/468, d=0.000
# >32, 343/468, d=0.000, g=14.248
# >Accuracy real: 100%, fake: 100%
# >32, 344/468, d=0.000, g=13.246
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 10ms/step
# >32, 345/468, d=0.004
# >32, 345/468, d=0.004, g=13.934
# >Accuracy real: 100%, fake: 100%
# >32, 346/468, d=0.004, g=13.903
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 12ms/step
# >32, 347/468, d=0.008
# >32, 347/468, d=0.008, g=14.094
# >Accuracy real: 100%, fake: 100%
# >32, 348/468, d=0.008, g=14.932
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 6ms/step
# >32, 349/468, d=0.011
# >32, 349/468, d=0.011, g=14.161
# >Accuracy real: 100%, fake: 100%
# >32, 350/468, d=0.011, g=15.095
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 7ms/step
# >32, 351/468, d=0.008
# >32, 351/468, d=0.008, g=15.299
# >Accuracy real: 100%, fake: 100%
# >32, 352/468, d=0.008, g=14.553
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 7ms/step
# >32, 353/468, d=0.012
# >32, 353/468, d=0.012, g=13.350
# >Accuracy real: 100%, fake: 100%
# >32, 354/468, d=0.012, g=13.736
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 12ms/step
# >32, 355/468, d=0.015
# >32, 355/468, d=0.015, g=13.211
# >Accuracy real: 100%, fake: 100%
# >32, 356/468, d=0.015, g=13.632
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 7ms/step
# >32, 357/468, d=0.017
# >32, 357/468, d=0.017, g=13.415
# >Accuracy real: 98%, fake: 100%
# >32, 358/468, d=0.017, g=13.663
# >Accuracy real: 98%, fake: 100%
# 2/2 [==============================] - 0s 18ms/step
# >32, 359/468, d=0.018
# >32, 359/468, d=0.018, g=13.682
# >Accuracy real: 100%, fake: 100%
# >32, 360/468, d=0.018, g=14.348
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 12ms/step
# >32, 361/468, d=0.013
# >32, 361/468, d=0.013, g=13.045
# >Accuracy real: 100%, fake: 100%
# >32, 362/468, d=0.013, g=13.709
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 7ms/step
# >32, 363/468, d=0.032
# >32, 363/468, d=0.032, g=13.598
# >Accuracy real: 100%, fake: 98%
# >32, 364/468, d=0.032, g=13.859
# >Accuracy real: 100%, fake: 98%
# 2/2 [==============================] - 0s 7ms/step
# >32, 365/468, d=0.013
# >32, 365/468, d=0.013, g=12.745
# >Accuracy real: 100%, fake: 100%
# >32, 366/468, d=0.013, g=15.213
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 7ms/step
# >32, 367/468, d=0.009
# >32, 367/468, d=0.009, g=14.047
# >Accuracy real: 100%, fake: 100%
# >32, 368/468, d=0.009, g=14.424
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 6ms/step
# >32, 369/468, d=0.011
# >32, 369/468, d=0.011, g=14.849
# >Accuracy real: 100%, fake: 100%
# >32, 370/468, d=0.011, g=16.397
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 14ms/step
# >32, 371/468, d=0.006
# >32, 371/468, d=0.006, g=13.928
# >Accuracy real: 100%, fake: 100%
# >32, 372/468, d=0.006, g=14.830
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 6ms/step
# >32, 373/468, d=0.004
# >32, 373/468, d=0.004, g=14.706
# >Accuracy real: 100%, fake: 100%
# >32, 374/468, d=0.004, g=14.360
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 14ms/step
# >32, 375/468, d=0.001
# >32, 375/468, d=0.001, g=14.293
# >Accuracy real: 100%, fake: 100%
# >32, 376/468, d=0.001, g=14.293
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 7ms/step
# >32, 377/468, d=0.009
# >32, 377/468, d=0.009, g=13.842
# >Accuracy real: 100%, fake: 100%
# >32, 378/468, d=0.009, g=14.403
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 13ms/step
# >32, 379/468, d=0.002
# >32, 379/468, d=0.002, g=13.570
# >Accuracy real: 100%, fake: 100%
# >32, 380/468, d=0.002, g=13.997
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 13ms/step
# >32, 381/468, d=0.002
# >32, 381/468, d=0.002, g=13.783
# >Accuracy real: 100%, fake: 100%
# >32, 382/468, d=0.002, g=13.329
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 6ms/step
# >32, 383/468, d=0.024
# >32, 383/468, d=0.024, g=14.654
# >Accuracy real: 100%, fake: 100%
# >32, 384/468, d=0.024, g=15.011
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 6ms/step
# >32, 385/468, d=0.010
# >32, 385/468, d=0.010, g=14.719
# >Accuracy real: 98%, fake: 100%
# >32, 386/468, d=0.010, g=14.285
# >Accuracy real: 98%, fake: 100%
# 2/2 [==============================] - 0s 12ms/step
# >32, 387/468, d=0.005
# >32, 387/468, d=0.005, g=15.054
# >Accuracy real: 100%, fake: 100%
# >32, 388/468, d=0.005, g=15.485
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 8ms/step
# >32, 389/468, d=0.004
# >32, 389/468, d=0.004, g=14.034
# >Accuracy real: 100%, fake: 100%
# >32, 390/468, d=0.004, g=13.440
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 11ms/step
# >32, 391/468, d=0.012
# >32, 391/468, d=0.012, g=15.590
# >Accuracy real: 100%, fake: 100%
# >32, 392/468, d=0.012, g=14.789
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 8ms/step
# >32, 393/468, d=0.011
# >32, 393/468, d=0.011, g=14.627
# >Accuracy real: 100%, fake: 100%
# >32, 394/468, d=0.011, g=14.086
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 6ms/step
# >32, 395/468, d=0.002
# >32, 395/468, d=0.002, g=13.526
# >Accuracy real: 100%, fake: 100%
# >32, 396/468, d=0.002, g=14.402
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 6ms/step
# >32, 397/468, d=0.001
# >32, 397/468, d=0.001, g=14.209
# >Accuracy real: 100%, fake: 100%
# >32, 398/468, d=0.001, g=14.052
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 6ms/step
# >32, 399/468, d=0.002
# >32, 399/468, d=0.002, g=12.929
# >Accuracy real: 100%, fake: 100%
# >32, 400/468, d=0.002, g=13.532
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 11ms/step
# >32, 401/468, d=0.013
# >32, 401/468, d=0.013, g=14.326
# >Accuracy real: 100%, fake: 100%
# >32, 402/468, d=0.013, g=13.902
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 16ms/step
# >32, 403/468, d=0.003
# >32, 403/468, d=0.003, g=14.390
# >Accuracy real: 100%, fake: 100%
# >32, 404/468, d=0.003, g=14.567
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 16ms/step
# >32, 405/468, d=0.003
# >32, 405/468, d=0.003, g=13.925
# >Accuracy real: 100%, fake: 100%
# >32, 406/468, d=0.003, g=13.755
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 6ms/step
# >32, 407/468, d=0.007
# >32, 407/468, d=0.007, g=14.256
# >Accuracy real: 100%, fake: 100%
# >32, 408/468, d=0.007, g=14.334
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 10ms/step
# >32, 409/468, d=0.008
# >32, 409/468, d=0.008, g=14.262
# >Accuracy real: 100%, fake: 100%
# >32, 410/468, d=0.008, g=14.155
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 7ms/step
# >32, 411/468, d=0.003
# >32, 411/468, d=0.003, g=16.179
# >Accuracy real: 100%, fake: 100%
# >32, 412/468, d=0.003, g=14.726
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 6ms/step
# >32, 413/468, d=0.011
# >32, 413/468, d=0.011, g=13.425
# >Accuracy real: 100%, fake: 100%
# >32, 414/468, d=0.011, g=13.788
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 17ms/step
# >32, 415/468, d=0.002
# >32, 415/468, d=0.002, g=13.853
# >Accuracy real: 100%, fake: 100%
# >32, 416/468, d=0.002, g=13.612
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 16ms/step
# >32, 417/468, d=0.005
# >32, 417/468, d=0.005, g=13.645
# >Accuracy real: 100%, fake: 100%
# >32, 418/468, d=0.005, g=13.723
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 11ms/step
# >32, 419/468, d=0.012
# >32, 419/468, d=0.012, g=14.324
# >Accuracy real: 100%, fake: 100%
# >32, 420/468, d=0.012, g=15.348
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 18ms/step
# >32, 421/468, d=0.019
# >32, 421/468, d=0.019, g=14.841
# >Accuracy real: 100%, fake: 100%
# >32, 422/468, d=0.019, g=15.097
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 12ms/step
# >32, 423/468, d=0.059
# >32, 423/468, d=0.059, g=14.205
# >Accuracy real: 98%, fake: 98%
# >32, 424/468, d=0.059, g=14.354
# >Accuracy real: 98%, fake: 98%
# 2/2 [==============================] - 0s 11ms/step
# >32, 425/468, d=0.008
# >32, 425/468, d=0.008, g=14.474
# >Accuracy real: 100%, fake: 100%
# >32, 426/468, d=0.008, g=13.942
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 7ms/step
# >32, 427/468, d=0.009
# >32, 427/468, d=0.009, g=13.996
# >Accuracy real: 100%, fake: 100%
# >32, 428/468, d=0.009, g=14.065
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 7ms/step
# >32, 429/468, d=0.002
# >32, 429/468, d=0.002, g=13.142
# >Accuracy real: 100%, fake: 100%
# >32, 430/468, d=0.002, g=13.250
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 6ms/step
# >32, 431/468, d=0.003
# >32, 431/468, d=0.003, g=14.525
# >Accuracy real: 100%, fake: 100%
# >32, 432/468, d=0.003, g=13.807
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 7ms/step
# >32, 433/468, d=0.001
# >32, 433/468, d=0.001, g=12.860
# >Accuracy real: 100%, fake: 100%
# >32, 434/468, d=0.001, g=13.727
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 12ms/step
# >32, 435/468, d=0.033
# >32, 435/468, d=0.033, g=13.490
# >Accuracy real: 100%, fake: 100%
# >32, 436/468, d=0.033, g=14.176
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 16ms/step
# >32, 437/468, d=0.008
# >32, 437/468, d=0.008, g=13.728
# >Accuracy real: 100%, fake: 100%
# >32, 438/468, d=0.008, g=15.154
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 13ms/step
# >32, 439/468, d=0.011
# >32, 439/468, d=0.011, g=14.440
# >Accuracy real: 100%, fake: 100%
# >32, 440/468, d=0.011, g=13.321
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 6ms/step
# >32, 441/468, d=0.002
# >32, 441/468, d=0.002, g=14.460
# >Accuracy real: 100%, fake: 100%
# >32, 442/468, d=0.002, g=15.137
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 8ms/step
# >32, 443/468, d=0.006
# >32, 443/468, d=0.006, g=14.587
# >Accuracy real: 100%, fake: 100%
# >32, 444/468, d=0.006, g=15.168
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 7ms/step
# >32, 445/468, d=0.003
# >32, 445/468, d=0.003, g=15.240
# >Accuracy real: 100%, fake: 100%
# >32, 446/468, d=0.003, g=13.898
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 11ms/step
# >32, 447/468, d=0.003
# >32, 447/468, d=0.003, g=15.095
# >Accuracy real: 100%, fake: 100%
# >32, 448/468, d=0.003, g=14.076
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 12ms/step
# >32, 449/468, d=0.008
# >32, 449/468, d=0.008, g=14.410
# >Accuracy real: 100%, fake: 100%
# >32, 450/468, d=0.008, g=13.709
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 15ms/step
# >32, 451/468, d=0.020
# >32, 451/468, d=0.020, g=13.744
# >Accuracy real: 100%, fake: 98%
# >32, 452/468, d=0.020, g=14.868
# >Accuracy real: 100%, fake: 98%
# 2/2 [==============================] - 0s 6ms/step
# >32, 453/468, d=0.012
# >32, 453/468, d=0.012, g=14.155
# >Accuracy real: 98%, fake: 100%
# >32, 454/468, d=0.012, g=13.734
# >Accuracy real: 98%, fake: 100%
# 2/2 [==============================] - 0s 11ms/step
# >32, 455/468, d=0.004
# >32, 455/468, d=0.004, g=14.104
# >Accuracy real: 100%, fake: 100%
# >32, 456/468, d=0.004, g=14.682
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 17ms/step
# >32, 457/468, d=0.005
# >32, 457/468, d=0.005, g=15.302
# >Accuracy real: 100%, fake: 100%
# >32, 458/468, d=0.005, g=15.108
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 6ms/step
# >32, 459/468, d=0.016
# >32, 459/468, d=0.016, g=14.086
# >Accuracy real: 100%, fake: 100%
# >32, 460/468, d=0.016, g=14.649
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 6ms/step
# >32, 461/468, d=0.004
# >32, 461/468, d=0.004, g=14.731
# >Accuracy real: 100%, fake: 100%
# >32, 462/468, d=0.004, g=14.700
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 12ms/step
# >32, 463/468, d=0.008
# >32, 463/468, d=0.008, g=15.149
# >Accuracy real: 100%, fake: 100%
# >32, 464/468, d=0.008, g=13.878
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 6ms/step
# >32, 465/468, d=0.007
# >32, 465/468, d=0.007, g=14.091
# >Accuracy real: 100%, fake: 100%
# >32, 466/468, d=0.007, g=14.423
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 6ms/step
# >32, 467/468, d=0.003
# >32, 467/468, d=0.003, g=13.456
# >Accuracy real: 100%, fake: 100%
# >32, 468/468, d=0.003, g=14.974
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 10ms/step
# >33, 1/468, d=0.014
# >33, 1/468, d=0.014, g=13.679
# >Accuracy real: 100%, fake: 100%
# >33, 2/468, d=0.014, g=14.236
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 13ms/step
# >33, 3/468, d=0.004
# >33, 3/468, d=0.004, g=13.716
# >Accuracy real: 100%, fake: 100%
# >33, 4/468, d=0.004, g=13.856
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 9ms/step
# >33, 5/468, d=0.013
# >33, 5/468, d=0.013, g=13.611
# >Accuracy real: 100%, fake: 100%
# >33, 6/468, d=0.013, g=14.196
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 14ms/step
# >33, 7/468, d=0.001
# >33, 7/468, d=0.001, g=14.241
# >Accuracy real: 100%, fake: 100%
# >33, 8/468, d=0.001, g=13.934
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 8ms/step
# >33, 9/468, d=0.008
# >33, 9/468, d=0.008, g=14.078
# >Accuracy real: 100%, fake: 100%
# >33, 10/468, d=0.008, g=14.534
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 13ms/step
# >33, 11/468, d=0.004
# >33, 11/468, d=0.004, g=14.631
# >Accuracy real: 100%, fake: 100%
# >33, 12/468, d=0.004, g=15.264
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 6ms/step
# >33, 13/468, d=0.010
# >33, 13/468, d=0.010, g=14.467
# >Accuracy real: 100%, fake: 100%
# >33, 14/468, d=0.010, g=13.584
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 7ms/step
# >33, 15/468, d=0.013
# >33, 15/468, d=0.013, g=14.338
# >Accuracy real: 100%, fake: 100%
# >33, 16/468, d=0.013, g=14.463
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 13ms/step
# >33, 17/468, d=0.004
# >33, 17/468, d=0.004, g=12.931
# >Accuracy real: 100%, fake: 100%
# >33, 18/468, d=0.004, g=12.628
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 6ms/step
# >33, 19/468, d=0.015
# >33, 19/468, d=0.015, g=13.833
# >Accuracy real: 100%, fake: 100%
# >33, 20/468, d=0.015, g=13.071
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 6ms/step
# >33, 21/468, d=0.017
# >33, 21/468, d=0.017, g=14.069
# >Accuracy real: 100%, fake: 100%
# >33, 22/468, d=0.017, g=14.515
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 7ms/step
# >33, 23/468, d=0.005
# >33, 23/468, d=0.005, g=14.535
# >Accuracy real: 100%, fake: 100%
# >33, 24/468, d=0.005, g=14.027
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 7ms/step
# >33, 25/468, d=0.011
# >33, 25/468, d=0.011, g=13.714
# >Accuracy real: 100%, fake: 100%
# >33, 26/468, d=0.011, g=13.741
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 11ms/step
# >33, 27/468, d=0.001
# >33, 27/468, d=0.001, g=13.259
# >Accuracy real: 100%, fake: 100%
# >33, 28/468, d=0.001, g=14.056
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 12ms/step
# >33, 29/468, d=0.011
# >33, 29/468, d=0.011, g=14.343
# >Accuracy real: 100%, fake: 100%
# >33, 30/468, d=0.011, g=14.460
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 7ms/step
# >33, 31/468, d=0.002
# >33, 31/468, d=0.002, g=14.654
# >Accuracy real: 100%, fake: 100%
# >33, 32/468, d=0.002, g=14.506
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 11ms/step
# >33, 33/468, d=0.026
# >33, 33/468, d=0.026, g=14.220
# >Accuracy real: 100%, fake: 100%
# >33, 34/468, d=0.026, g=13.579
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 8ms/step
# >33, 35/468, d=0.015
# >33, 35/468, d=0.015, g=13.304
# >Accuracy real: 100%, fake: 100%
# >33, 36/468, d=0.015, g=13.701
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 13ms/step
# >33, 37/468, d=0.002
# >33, 37/468, d=0.002, g=13.675
# >Accuracy real: 100%, fake: 100%
# >33, 38/468, d=0.002, g=13.535
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 6ms/step
# >33, 39/468, d=0.017
# >33, 39/468, d=0.017, g=13.619
# >Accuracy real: 100%, fake: 100%
# >33, 40/468, d=0.017, g=14.128
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 7ms/step
# >33, 41/468, d=0.016
# >33, 41/468, d=0.016, g=14.453
# >Accuracy real: 100%, fake: 98%
# >33, 42/468, d=0.016, g=14.862
# >Accuracy real: 100%, fake: 98%
# 2/2 [==============================] - 0s 10ms/step
# >33, 43/468, d=0.008
# >33, 43/468, d=0.008, g=14.737
# >Accuracy real: 100%, fake: 100%
# >33, 44/468, d=0.008, g=13.844
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 7ms/step
# >33, 45/468, d=0.003
# >33, 45/468, d=0.003, g=13.882
# >Accuracy real: 100%, fake: 100%
# >33, 46/468, d=0.003, g=14.304
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 9ms/step
# >33, 47/468, d=0.002
# >33, 47/468, d=0.002, g=13.421
# >Accuracy real: 100%, fake: 100%
# >33, 48/468, d=0.002, g=14.670
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 9ms/step
# >33, 49/468, d=0.019
# >33, 49/468, d=0.019, g=15.024
# >Accuracy real: 100%, fake: 100%
# >33, 50/468, d=0.019, g=14.316
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 7ms/step
# >33, 51/468, d=0.010
# >33, 51/468, d=0.010, g=13.897
# >Accuracy real: 100%, fake: 100%
# >33, 52/468, d=0.010, g=14.483
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 6ms/step
# >33, 53/468, d=0.002
# >33, 53/468, d=0.002, g=14.140
# >Accuracy real: 100%, fake: 100%
# >33, 54/468, d=0.002, g=13.673
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 7ms/step
# >33, 55/468, d=0.009
# >33, 55/468, d=0.009, g=14.189
# >Accuracy real: 100%, fake: 100%
# >33, 56/468, d=0.009, g=14.306
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 8ms/step
# >33, 57/468, d=0.002
# >33, 57/468, d=0.002, g=14.827
# >Accuracy real: 100%, fake: 100%
# >33, 58/468, d=0.002, g=14.497
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 10ms/step
# >33, 59/468, d=0.007
# >33, 59/468, d=0.007, g=14.155
# >Accuracy real: 100%, fake: 100%
# >33, 60/468, d=0.007, g=15.820
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 7ms/step
# >33, 61/468, d=0.011
# >33, 61/468, d=0.011, g=14.095
# >Accuracy real: 100%, fake: 100%
# >33, 62/468, d=0.011, g=14.337
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 10ms/step
# >33, 63/468, d=0.013
# >33, 63/468, d=0.013, g=13.324
# >Accuracy real: 100%, fake: 100%
# >33, 64/468, d=0.013, g=13.971
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 7ms/step
# >33, 65/468, d=0.001
# >33, 65/468, d=0.001, g=12.837
# >Accuracy real: 100%, fake: 100%
# >33, 66/468, d=0.001, g=14.479
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 6ms/step
# >33, 67/468, d=0.001
# >33, 67/468, d=0.001, g=13.295
# >Accuracy real: 100%, fake: 100%
# >33, 68/468, d=0.001, g=13.356
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 8ms/step
# >33, 69/468, d=0.004
# >33, 69/468, d=0.004, g=13.459
# >Accuracy real: 100%, fake: 100%
# >33, 70/468, d=0.004, g=13.703
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 10ms/step
# >33, 71/468, d=0.005
# >33, 71/468, d=0.005, g=13.708
# >Accuracy real: 100%, fake: 100%
# >33, 72/468, d=0.005, g=14.088
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 11ms/step
# >33, 73/468, d=0.001
# >33, 73/468, d=0.001, g=12.833
# >Accuracy real: 100%, fake: 100%
# >33, 74/468, d=0.001, g=14.474
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 7ms/step
# >33, 75/468, d=0.001
# >33, 75/468, d=0.001, g=13.636
# >Accuracy real: 100%, fake: 100%
# >33, 76/468, d=0.001, g=14.271
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 6ms/step
# >33, 77/468, d=0.002
# >33, 77/468, d=0.002, g=12.571
# >Accuracy real: 100%, fake: 100%
# >33, 78/468, d=0.002, g=14.142
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 16ms/step
# >33, 79/468, d=0.005
# >33, 79/468, d=0.005, g=13.834
# >Accuracy real: 100%, fake: 100%
# >33, 80/468, d=0.005, g=13.788
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 7ms/step
# >33, 81/468, d=0.019
# >33, 81/468, d=0.019, g=14.986
# >Accuracy real: 100%, fake: 100%
# >33, 82/468, d=0.019, g=14.685
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 7ms/step
# >33, 83/468, d=0.016
# >33, 83/468, d=0.016, g=13.992
# >Accuracy real: 100%, fake: 100%
# >33, 84/468, d=0.016, g=14.641
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 7ms/step
# >33, 85/468, d=0.008
# >33, 85/468, d=0.008, g=13.756
# >Accuracy real: 100%, fake: 100%
# >33, 86/468, d=0.008, g=13.476
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 6ms/step
# >33, 87/468, d=0.035
# >33, 87/468, d=0.035, g=14.935
# >Accuracy real: 100%, fake: 100%
# >33, 88/468, d=0.035, g=14.499
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 12ms/step
# >33, 89/468, d=0.021
# >33, 89/468, d=0.021, g=14.440
# >Accuracy real: 100%, fake: 100%
# >33, 90/468, d=0.021, g=15.429
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 6ms/step
# >33, 91/468, d=0.010
# >33, 91/468, d=0.010, g=14.822
# >Accuracy real: 100%, fake: 100%
# >33, 92/468, d=0.010, g=15.252
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 6ms/step
# >33, 93/468, d=0.005
# >33, 93/468, d=0.005, g=14.867
# >Accuracy real: 100%, fake: 100%
# >33, 94/468, d=0.005, g=13.966
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 11ms/step
# >33, 95/468, d=0.001
# >33, 95/468, d=0.001, g=13.734
# >Accuracy real: 100%, fake: 100%
# >33, 96/468, d=0.001, g=13.636
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 6ms/step
# >33, 97/468, d=0.006
# >33, 97/468, d=0.006, g=13.530
# >Accuracy real: 100%, fake: 100%
# >33, 98/468, d=0.006, g=14.451
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 15ms/step
# >33, 99/468, d=0.002
# >33, 99/468, d=0.002, g=13.917
# >Accuracy real: 100%, fake: 100%
# >33, 100/468, d=0.002, g=14.416
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 6ms/step
# >33, 101/468, d=0.008
# >33, 101/468, d=0.008, g=14.904
# >Accuracy real: 100%, fake: 100%
# >33, 102/468, d=0.008, g=15.022
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 5ms/step
# >33, 103/468, d=0.010
# >33, 103/468, d=0.010, g=14.424
# >Accuracy real: 100%, fake: 100%
# >33, 104/468, d=0.010, g=14.245
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 5ms/step
# >33, 105/468, d=0.011
# >33, 105/468, d=0.011, g=14.962
# >Accuracy real: 100%, fake: 100%
# >33, 106/468, d=0.011, g=13.622
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 10ms/step
# >33, 107/468, d=0.005
# >33, 107/468, d=0.005, g=13.376
# >Accuracy real: 98%, fake: 100%
# >33, 108/468, d=0.005, g=14.310
# >Accuracy real: 98%, fake: 100%
# 2/2 [==============================] - 0s 5ms/step
# >33, 109/468, d=0.002
# >33, 109/468, d=0.002, g=14.339
# >Accuracy real: 100%, fake: 100%
# >33, 110/468, d=0.002, g=13.403
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 5ms/step
# >33, 111/468, d=0.006
# >33, 111/468, d=0.006, g=14.880
# >Accuracy real: 100%, fake: 100%
# >33, 112/468, d=0.006, g=15.481
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 9ms/step
# >33, 113/468, d=0.002
# >33, 113/468, d=0.002, g=14.477
# >Accuracy real: 100%, fake: 100%
# >33, 114/468, d=0.002, g=16.192
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 5ms/step
# >33, 115/468, d=0.004
# >33, 115/468, d=0.004, g=14.766
# >Accuracy real: 100%, fake: 100%
# >33, 116/468, d=0.004, g=16.183
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 6ms/step
# >33, 117/468, d=0.038
# >33, 117/468, d=0.038, g=15.040
# >Accuracy real: 98%, fake: 100%
# >33, 118/468, d=0.038, g=15.075
# >Accuracy real: 98%, fake: 100%
# 2/2 [==============================] - 0s 7ms/step
# >33, 119/468, d=0.007
# >33, 119/468, d=0.007, g=14.110
# >Accuracy real: 100%, fake: 100%
# >33, 120/468, d=0.007, g=13.333
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 13ms/step
# >33, 121/468, d=0.009
# >33, 121/468, d=0.009, g=14.894
# >Accuracy real: 100%, fake: 100%
# >33, 122/468, d=0.009, g=14.308
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 7ms/step
# >33, 123/468, d=0.006
# >33, 123/468, d=0.006, g=16.194
# >Accuracy real: 100%, fake: 100%
# >33, 124/468, d=0.006, g=14.827
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 7ms/step
# >33, 125/468, d=0.004
# >33, 125/468, d=0.004, g=15.930
# >Accuracy real: 100%, fake: 100%
# >33, 126/468, d=0.004, g=14.988
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 6ms/step
# >33, 127/468, d=0.004
# >33, 127/468, d=0.004, g=14.734
# >Accuracy real: 100%, fake: 100%
# >33, 128/468, d=0.004, g=16.177
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 9ms/step
# >33, 129/468, d=0.012
# >33, 129/468, d=0.012, g=14.966
# >Accuracy real: 100%, fake: 100%
# >33, 130/468, d=0.012, g=14.451
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 12ms/step
# >33, 131/468, d=0.006
# >33, 131/468, d=0.006, g=15.635
# >Accuracy real: 100%, fake: 100%
# >33, 132/468, d=0.006, g=13.954
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 11ms/step
# >33, 133/468, d=0.013
# >33, 133/468, d=0.013, g=14.441
# >Accuracy real: 100%, fake: 100%
# >33, 134/468, d=0.013, g=14.227
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 13ms/step
# >33, 135/468, d=0.007
# >33, 135/468, d=0.007, g=14.937
# >Accuracy real: 100%, fake: 100%
# >33, 136/468, d=0.007, g=13.803
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 9ms/step
# >33, 137/468, d=0.002
# >33, 137/468, d=0.002, g=15.219
# >Accuracy real: 100%, fake: 100%
# >33, 138/468, d=0.002, g=13.881
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 15ms/step
# >33, 139/468, d=0.002
# >33, 139/468, d=0.002, g=13.232
# >Accuracy real: 100%, fake: 100%
# >33, 140/468, d=0.002, g=13.808
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 6ms/step
# >33, 141/468, d=0.015
# >33, 141/468, d=0.015, g=15.052
# >Accuracy real: 98%, fake: 100%
# >33, 142/468, d=0.015, g=14.206
# >Accuracy real: 98%, fake: 100%
# 2/2 [==============================] - 0s 14ms/step
# >33, 143/468, d=0.004
# >33, 143/468, d=0.004, g=14.259
# >Accuracy real: 100%, fake: 100%
# >33, 144/468, d=0.004, g=14.521
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 7ms/step
# >33, 145/468, d=0.018
# >33, 145/468, d=0.018, g=15.862
# >Accuracy real: 100%, fake: 98%
# >33, 146/468, d=0.018, g=15.167
# >Accuracy real: 100%, fake: 98%
# 2/2 [==============================] - 0s 14ms/step
# >33, 147/468, d=0.006
# >33, 147/468, d=0.006, g=16.460
# >Accuracy real: 100%, fake: 100%
# >33, 148/468, d=0.006, g=15.036
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 11ms/step
# >33, 149/468, d=0.004
# >33, 149/468, d=0.004, g=16.030
# >Accuracy real: 100%, fake: 100%
# >33, 150/468, d=0.004, g=16.358
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 11ms/step
# >33, 151/468, d=0.048
# >33, 151/468, d=0.048, g=15.736
# >Accuracy real: 100%, fake: 100%
# >33, 152/468, d=0.048, g=15.672
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 6ms/step
# >33, 153/468, d=0.016
# >33, 153/468, d=0.016, g=14.489
# >Accuracy real: 100%, fake: 100%
# >33, 154/468, d=0.016, g=14.713
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 6ms/step
# >33, 155/468, d=0.004
# >33, 155/468, d=0.004, g=13.752
# >Accuracy real: 100%, fake: 100%
# >33, 156/468, d=0.004, g=14.540
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 16ms/step
# >33, 157/468, d=0.029
# >33, 157/468, d=0.029, g=13.792
# >Accuracy real: 100%, fake: 100%
# >33, 158/468, d=0.029, g=15.956
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 10ms/step
# >33, 159/468, d=0.018
# >33, 159/468, d=0.018, g=15.344
# >Accuracy real: 100%, fake: 100%
# >33, 160/468, d=0.018, g=16.726
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 7ms/step
# >33, 161/468, d=0.003
# >33, 161/468, d=0.003, g=16.456
# >Accuracy real: 100%, fake: 100%
# >33, 162/468, d=0.003, g=16.839
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 14ms/step
# >33, 163/468, d=0.008
# >33, 163/468, d=0.008, g=15.359
# >Accuracy real: 100%, fake: 100%
# >33, 164/468, d=0.008, g=15.431
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 6ms/step
# >33, 165/468, d=0.010
# >33, 165/468, d=0.010, g=16.606
# >Accuracy real: 100%, fake: 100%
# >33, 166/468, d=0.010, g=14.358
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 13ms/step
# >33, 167/468, d=0.014
# >33, 167/468, d=0.014, g=13.642
# >Accuracy real: 100%, fake: 100%
# >33, 168/468, d=0.014, g=13.846
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 11ms/step
# >33, 169/468, d=0.010
# >33, 169/468, d=0.010, g=14.023
# >Accuracy real: 100%, fake: 100%
# >33, 170/468, d=0.010, g=15.917
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 8ms/step
# >33, 171/468, d=0.009
# >33, 171/468, d=0.009, g=15.146
# >Accuracy real: 100%, fake: 100%
# >33, 172/468, d=0.009, g=15.110
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 9ms/step
# >33, 173/468, d=0.006
# >33, 173/468, d=0.006, g=16.194
# >Accuracy real: 100%, fake: 100%
# >33, 174/468, d=0.006, g=16.056
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 11ms/step
# >33, 175/468, d=0.006
# >33, 175/468, d=0.006, g=15.381
# >Accuracy real: 100%, fake: 100%
# >33, 176/468, d=0.006, g=15.207
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 13ms/step
# >33, 177/468, d=0.023
# >33, 177/468, d=0.023, g=15.755
# >Accuracy real: 100%, fake: 100%
# >33, 178/468, d=0.023, g=14.894
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 7ms/step
# >33, 179/468, d=0.007
# >33, 179/468, d=0.007, g=13.589
# >Accuracy real: 100%, fake: 100%
# >33, 180/468, d=0.007, g=14.993
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 10ms/step
# >33, 181/468, d=0.006
# >33, 181/468, d=0.006, g=15.122
# >Accuracy real: 100%, fake: 100%
# >33, 182/468, d=0.006, g=15.844
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 16ms/step
# >33, 183/468, d=0.012
# >33, 183/468, d=0.012, g=15.430
# >Accuracy real: 100%, fake: 100%
# >33, 184/468, d=0.012, g=15.220
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 6ms/step
# >33, 185/468, d=0.018
# >33, 185/468, d=0.018, g=14.785
# >Accuracy real: 100%, fake: 100%
# >33, 186/468, d=0.018, g=17.178
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 12ms/step
# >33, 187/468, d=0.009
# >33, 187/468, d=0.009, g=16.645
# >Accuracy real: 100%, fake: 100%
# >33, 188/468, d=0.009, g=14.517
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 16ms/step
# >33, 189/468, d=0.002
# >33, 189/468, d=0.002, g=16.071
# >Accuracy real: 100%, fake: 100%
# >33, 190/468, d=0.002, g=15.898
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 7ms/step
# >33, 191/468, d=0.007
# >33, 191/468, d=0.007, g=16.187
# >Accuracy real: 100%, fake: 100%
# >33, 192/468, d=0.007, g=15.351
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 15ms/step
# >33, 193/468, d=0.004
# >33, 193/468, d=0.004, g=14.527
# >Accuracy real: 100%, fake: 100%
# >33, 194/468, d=0.004, g=15.350
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 11ms/step
# >33, 195/468, d=0.011
# >33, 195/468, d=0.011, g=14.346
# >Accuracy real: 100%, fake: 100%
# >33, 196/468, d=0.011, g=15.082
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 7ms/step
# >33, 197/468, d=0.007
# >33, 197/468, d=0.007, g=15.227
# >Accuracy real: 100%, fake: 100%
# >33, 198/468, d=0.007, g=14.886
# >Accuracy real: 100%, fake: 100%
# ...
# >35, 299/468, d=0.003
# >35, 299/468, d=0.003, g=16.123
# >Accuracy real: 100%, fake: 100%
# >35, 300/468, d=0.003, g=16.094
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 7ms/step
# >35, 301/468, d=0.011
# >35, 301/468, d=0.011, g=16.993
# >Accuracy real: 100%, fake: 100%
# >35, 302/468, d=0.011, g=15.150
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 11ms/step
# >35, 303/468, d=0.003
# >35, 303/468, d=0.003, g=15.550
# >Accuracy real: 100%, fake: 100%
# >35, 304/468, d=0.003, g=15.150
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 7ms/step
# >35, 305/468, d=0.002
# >35, 305/468, d=0.002, g=14.625
# >Accuracy real: 100%, fake: 100%
# >35, 306/468, d=0.002, g=15.363
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 17ms/step
# >35, 307/468, d=0.021
# >35, 307/468, d=0.021, g=15.373
# >Accuracy real: 100%, fake: 98%
# >35, 308/468, d=0.021, g=16.022
# >Accuracy real: 100%, fake: 98%
# 2/2 [==============================] - 0s 9ms/step
# >35, 309/468, d=0.001
# >35, 309/468, d=0.001, g=16.626
# >Accuracy real: 100%, fake: 100%
# >35, 310/468, d=0.001, g=16.531
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 16ms/step
# >35, 311/468, d=0.001
# >35, 311/468, d=0.001, g=16.880
# >Accuracy real: 100%, fake: 100%
# >35, 312/468, d=0.001, g=14.523
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 6ms/step
# >35, 313/468, d=0.002
# >35, 313/468, d=0.002, g=15.939
# >Accuracy real: 100%, fake: 100%
# >35, 314/468, d=0.002, g=15.013
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 16ms/step
# >35, 315/468, d=0.001
# >35, 315/468, d=0.001, g=15.391
# >Accuracy real: 100%, fake: 100%
# >35, 316/468, d=0.001, g=16.158
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 15ms/step
# >35, 317/468, d=0.002
# >35, 317/468, d=0.002, g=15.781
# >Accuracy real: 100%, fake: 100%
# >35, 318/468, d=0.002, g=14.888
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 14ms/step
# >35, 319/468, d=0.007
# >35, 319/468, d=0.007, g=13.845
# >Accuracy real: 100%, fake: 100%
# >35, 320/468, d=0.007, g=14.528
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 11ms/step
# >35, 321/468, d=0.006
# >35, 321/468, d=0.006, g=14.755
# >Accuracy real: 100%, fake: 100%
# >35, 322/468, d=0.006, g=16.351
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 7ms/step
# >35, 323/468, d=0.002
# >35, 323/468, d=0.002, g=14.778
# >Accuracy real: 100%, fake: 100%
# >35, 324/468, d=0.002, g=14.541
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 7ms/step
# >35, 325/468, d=0.034
# >35, 325/468, d=0.034, g=16.817
# >Accuracy real: 98%, fake: 100%
# >35, 326/468, d=0.034, g=15.778
# >Accuracy real: 98%, fake: 100%
# 2/2 [==============================] - 0s 14ms/step
# >35, 327/468, d=0.001
# >35, 327/468, d=0.001, g=16.591
# >Accuracy real: 100%, fake: 100%
# >35, 328/468, d=0.001, g=17.953
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 14ms/step
# >35, 329/468, d=0.005
# >35, 329/468, d=0.005, g=18.573
# >Accuracy real: 100%, fake: 100%
# >35, 330/468, d=0.005, g=16.599
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 7ms/step
# >35, 331/468, d=0.008
# >35, 331/468, d=0.008, g=17.125
# >Accuracy real: 100%, fake: 100%
# >35, 332/468, d=0.008, g=17.111
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 7ms/step
# >35, 333/468, d=0.003
# >35, 333/468, d=0.003, g=17.759
# >Accuracy real: 100%, fake: 100%
# >35, 334/468, d=0.003, g=17.058
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 11ms/step
# >35, 335/468, d=0.017
# >35, 335/468, d=0.017, g=15.623
# >Accuracy real: 100%, fake: 100%
# >35, 336/468, d=0.017, g=17.072
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 7ms/step
# >35, 337/468, d=0.016
# >35, 337/468, d=0.016, g=14.292
# >Accuracy real: 100%, fake: 100%
# >35, 338/468, d=0.016, g=13.482
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 7ms/step
# >35, 339/468, d=0.002
# >35, 339/468, d=0.002, g=14.043
# >Accuracy real: 100%, fake: 100%
# >35, 340/468, d=0.002, g=13.443
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 7ms/step
# >35, 341/468, d=0.040
# >35, 341/468, d=0.040, g=15.448
# >Accuracy real: 100%, fake: 100%
# >35, 342/468, d=0.040, g=15.059
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 8ms/step
# >35, 343/468, d=0.005
# >35, 343/468, d=0.005, g=18.000
# >Accuracy real: 100%, fake: 100%
# >35, 344/468, d=0.005, g=15.305
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 7ms/step
# >35, 345/468, d=0.005
# >35, 345/468, d=0.005, g=15.379
# >Accuracy real: 100%, fake: 100%
# >35, 346/468, d=0.005, g=15.809
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 6ms/step
# >35, 347/468, d=0.005
# >35, 347/468, d=0.005, g=15.031
# >Accuracy real: 100%, fake: 100%
# >35, 348/468, d=0.005, g=15.785
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 11ms/step
# >35, 349/468, d=0.004
# >35, 349/468, d=0.004, g=15.444
# >Accuracy real: 100%, fake: 100%
# >35, 350/468, d=0.004, g=15.715
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 7ms/step
# >35, 351/468, d=0.038
# >35, 351/468, d=0.038, g=15.964
# >Accuracy real: 98%, fake: 100%
# >35, 352/468, d=0.038, g=15.191
# >Accuracy real: 98%, fake: 100%
# 2/2 [==============================] - 0s 7ms/step
# >35, 353/468, d=0.002
# >35, 353/468, d=0.002, g=16.558
# >Accuracy real: 100%, fake: 100%
# >35, 354/468, d=0.002, g=15.393
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 11ms/step
# >35, 355/468, d=0.021
# >35, 355/468, d=0.021, g=15.513
# >Accuracy real: 100%, fake: 100%
# >35, 356/468, d=0.021, g=15.686
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 7ms/step
# >35, 357/468, d=0.008
# >35, 357/468, d=0.008, g=13.104
# >Accuracy real: 100%, fake: 100%
# >35, 358/468, d=0.008, g=15.111
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 7ms/step
# >35, 359/468, d=0.003
# >35, 359/468, d=0.003, g=14.920
# >Accuracy real: 100%, fake: 100%
# >35, 360/468, d=0.003, g=15.567
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 14ms/step
# >35, 361/468, d=0.005
# >35, 361/468, d=0.005, g=14.967
# >Accuracy real: 100%, fake: 100%
# >35, 362/468, d=0.005, g=15.152
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 6ms/step
# >35, 363/468, d=0.001
# >35, 363/468, d=0.001, g=13.911
# >Accuracy real: 100%, fake: 100%
# >35, 364/468, d=0.001, g=13.999
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 13ms/step
# >35, 365/468, d=0.027
# >35, 365/468, d=0.027, g=15.683
# >Accuracy real: 100%, fake: 98%
# >35, 366/468, d=0.027, g=14.943
# >Accuracy real: 100%, fake: 98%
# 2/2 [==============================] - 0s 7ms/step
# >35, 367/468, d=0.002
# >35, 367/468, d=0.002, g=16.661
# >Accuracy real: 100%, fake: 100%
# >35, 368/468, d=0.002, g=15.123
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 7ms/step
# >35, 369/468, d=0.001
# >35, 369/468, d=0.001, g=16.221
# >Accuracy real: 100%, fake: 100%
# >35, 370/468, d=0.001, g=15.000
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 11ms/step
# >35, 371/468, d=0.005
# >35, 371/468, d=0.005, g=16.791
# >Accuracy real: 100%, fake: 100%
# >35, 372/468, d=0.005, g=15.456
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 14ms/step
# >35, 373/468, d=0.011
# >35, 373/468, d=0.011, g=15.378
# >Accuracy real: 100%, fake: 100%
# >35, 374/468, d=0.011, g=15.238
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 10ms/step
# >35, 375/468, d=0.009
# >35, 375/468, d=0.009, g=15.011
# >Accuracy real: 100%, fake: 100%
# >35, 376/468, d=0.009, g=15.728
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 9ms/step
# >35, 377/468, d=0.001
# >35, 377/468, d=0.001, g=15.915
# >Accuracy real: 100%, fake: 100%
# >35, 378/468, d=0.001, g=16.154
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 8ms/step
# >35, 379/468, d=0.018
# >35, 379/468, d=0.018, g=14.647
# >Accuracy real: 100%, fake: 100%
# >35, 380/468, d=0.018, g=16.118
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 13ms/step
# >35, 381/468, d=0.001
# >35, 381/468, d=0.001, g=16.211
# >Accuracy real: 100%, fake: 100%
# >35, 382/468, d=0.001, g=14.355
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 6ms/step
# >35, 383/468, d=0.001
# >35, 383/468, d=0.001, g=14.952
# >Accuracy real: 100%, fake: 100%
# >35, 384/468, d=0.001, g=15.269
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 7ms/step
# >35, 385/468, d=0.001
# >35, 385/468, d=0.001, g=14.605
# >Accuracy real: 100%, fake: 100%
# >35, 386/468, d=0.001, g=15.845
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 12ms/step
# >35, 387/468, d=0.009
# >35, 387/468, d=0.009, g=15.822
# >Accuracy real: 100%, fake: 100%
# >35, 388/468, d=0.009, g=15.632
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 15ms/step
# >35, 389/468, d=0.013
# >35, 389/468, d=0.013, g=14.764
# >Accuracy real: 100%, fake: 100%
# >35, 390/468, d=0.013, g=15.385
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 7ms/step
# >35, 391/468, d=0.006
# >35, 391/468, d=0.006, g=15.593
# >Accuracy real: 100%, fake: 100%
# >35, 392/468, d=0.006, g=14.304
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 12ms/step
# >35, 393/468, d=0.008
# >35, 393/468, d=0.008, g=15.316
# >Accuracy real: 100%, fake: 100%
# >35, 394/468, d=0.008, g=14.787
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 9ms/step
# >35, 395/468, d=0.004
# >35, 395/468, d=0.004, g=14.146
# >Accuracy real: 100%, fake: 100%
# >35, 396/468, d=0.004, g=13.995
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 7ms/step
# >35, 397/468, d=0.000
# >35, 397/468, d=0.000, g=14.048
# >Accuracy real: 100%, fake: 100%
# >35, 398/468, d=0.000, g=14.420
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 17ms/step
# >35, 399/468, d=0.012
# >35, 399/468, d=0.012, g=14.333
# >Accuracy real: 100%, fake: 100%
# >35, 400/468, d=0.012, g=15.548
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 12ms/step
# >35, 401/468, d=0.001
# >35, 401/468, d=0.001, g=14.193
# >Accuracy real: 100%, fake: 100%
# >35, 402/468, d=0.001, g=14.690
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 8ms/step
# >35, 403/468, d=0.001
# >35, 403/468, d=0.001, g=16.055
# >Accuracy real: 100%, fake: 100%
# >35, 404/468, d=0.001, g=15.776
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 12ms/step
# >35, 405/468, d=0.001
# >35, 405/468, d=0.001, g=14.542
# >Accuracy real: 100%, fake: 100%
# >35, 406/468, d=0.001, g=15.542
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 7ms/step
# >35, 407/468, d=0.004
# >35, 407/468, d=0.004, g=16.165
# >Accuracy real: 100%, fake: 100%
# >35, 408/468, d=0.004, g=14.910
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 11ms/step
# >35, 409/468, d=0.005
# >35, 409/468, d=0.005, g=15.962
# >Accuracy real: 100%, fake: 100%
# >35, 410/468, d=0.005, g=15.739
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 8ms/step
# >35, 411/468, d=0.023
# >35, 411/468, d=0.023, g=16.836
# >Accuracy real: 98%, fake: 98%
# >35, 412/468, d=0.023, g=15.729
# >Accuracy real: 98%, fake: 98%
# 2/2 [==============================] - 0s 6ms/step
# >35, 413/468, d=0.018
# >35, 413/468, d=0.018, g=16.261
# >Accuracy real: 100%, fake: 100%
# >35, 414/468, d=0.018, g=15.236
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 6ms/step
# >35, 415/468, d=0.009
# >35, 415/468, d=0.009, g=15.921
# >Accuracy real: 100%, fake: 100%
# >35, 416/468, d=0.009, g=17.380
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 6ms/step
# >35, 417/468, d=0.010
# >35, 417/468, d=0.010, g=17.602
# >Accuracy real: 100%, fake: 100%
# >35, 418/468, d=0.010, g=17.101
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 14ms/step
# >35, 419/468, d=0.007
# >35, 419/468, d=0.007, g=15.369
# >Accuracy real: 100%, fake: 100%
# >35, 420/468, d=0.007, g=16.491
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 11ms/step
# >35, 421/468, d=0.002
# >35, 421/468, d=0.002, g=14.925
# >Accuracy real: 100%, fake: 100%
# >35, 422/468, d=0.002, g=16.547
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 7ms/step
# >35, 423/468, d=0.012
# >35, 423/468, d=0.012, g=16.738
# >Accuracy real: 100%, fake: 100%
# >35, 424/468, d=0.012, g=16.991
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 14ms/step
# >35, 425/468, d=0.003
# >35, 425/468, d=0.003, g=16.338
# >Accuracy real: 100%, fake: 100%
# >35, 426/468, d=0.003, g=17.587
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 7ms/step
# >35, 427/468, d=0.005
# >35, 427/468, d=0.005, g=16.014
# >Accuracy real: 100%, fake: 100%
# >35, 428/468, d=0.005, g=16.177
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 12ms/step
# >35, 429/468, d=0.006
# >35, 429/468, d=0.006, g=14.450
# >Accuracy real: 100%, fake: 100%
# >35, 430/468, d=0.006, g=15.329
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 7ms/step
# >35, 431/468, d=0.002
# >35, 431/468, d=0.002, g=16.145
# >Accuracy real: 100%, fake: 100%
# >35, 432/468, d=0.002, g=15.066
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 13ms/step
# >35, 433/468, d=0.004
# >35, 433/468, d=0.004, g=15.628
# >Accuracy real: 100%, fake: 100%
# >35, 434/468, d=0.004, g=15.847
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 12ms/step
# >35, 435/468, d=0.002
# >35, 435/468, d=0.002, g=16.884
# >Accuracy real: 100%, fake: 100%
# >35, 436/468, d=0.002, g=15.640
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 13ms/step
# >35, 437/468, d=0.004
# >35, 437/468, d=0.004, g=15.297
# >Accuracy real: 100%, fake: 100%
# >35, 438/468, d=0.004, g=15.527
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 13ms/step
# >35, 439/468, d=0.011
# >35, 439/468, d=0.011, g=16.233
# >Accuracy real: 100%, fake: 100%
# >35, 440/468, d=0.011, g=14.275
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 13ms/step
# >35, 441/468, d=0.001
# >35, 441/468, d=0.001, g=15.159
# >Accuracy real: 100%, fake: 100%
# >35, 442/468, d=0.001, g=14.932
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 9ms/step
# >35, 443/468, d=0.004
# >35, 443/468, d=0.004, g=15.357
# >Accuracy real: 100%, fake: 100%
# >35, 444/468, d=0.004, g=15.368
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 10ms/step
# >35, 445/468, d=0.003
# >35, 445/468, d=0.003, g=16.072
# >Accuracy real: 100%, fake: 100%
# >35, 446/468, d=0.003, g=16.302
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 0s 15ms/step
# >35, 447/468, d=0.002
# >35, 447/468, d=0.002, g=16.217
# >Accuracy real: 100%, fake: 100%
# >35, 448/468, d=0.002, g=16.078
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 1s 372ms/step
# >35, 449/468, d=0.001
# >35, 449/468, d=0.001, g=16.830
# >Accuracy real: 100%, fake: 100%
# >35, 450/468, d=0.001, g=15.775
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 2s 527ms/step
# >35, 451/468, d=0.002
# >35, 451/468, d=0.002, g=15.490
# >Accuracy real: 100%, fake: 100%
# >35, 452/468, d=0.002, g=15.681
# >Accuracy real: 100%, fake: 100%
# 2/2 [==============================] - 4s 979ms/step
# >35, 453/468, d=0.011
# >35, 453/468, d=0.011, g=16.607
# >Accuracy real: 100%, fake: 98%
# >35, 454/468, d=0.011, g=15.486
# >Accuracy real: 100%, fake: 98%
# 2/2 [==============================] - 15s 2s/step
# >35, 455/468, d=0.003
# >35, 455/468, d=0.003, g=15.513
# >Accuracy real: 100%, fake: 100%
# >35, 456/468, d=0.003, g=15.696

# %%
# đánh giá accuracy của discriminator trên cả tập real và tập fake
def summarize_performance(epoch, gan_model, X_real, y_real, X_fake, y_fake):
	_, acc_real = gan_model.layers[1].evaluate(X_real, y_real, verbose=0)
	_, acc_fake = gan_model.layers[1].evaluate(X_fake, y_fake, verbose=0)
	# thống kê discriminator performance
	print('>Accuracy real: %.0f%%, fake: %.0f%%' % (acc_real*100, acc_fake*100))

# %%
X_eval, y_eval = generate_fake_samples(g_model=gan_model.layers[0], latent_dim=128, n_samples=25)

_plot(X_eval[:, :, :, 0])
# Out:
# 1/1 [==============================] - 0s 270ms/step

# %%
loss, acc = d_model.evaluate(eval_x, eval_y)
# Out:
# 224/224 [==============================] - 1s 4ms/step - loss: 43.1364 - accuracy: 0.5799
