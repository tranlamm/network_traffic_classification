# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
main_dir = '/content/drive/MyDrive/Colab Notebooks/NTC'
checkpoint_py = '/content/drive/MyDrive/Colab Notebooks/FL/checkpoint_manager.py'
utils_py = '/content/drive/MyDrive/Colab Notebooks/FL/utils.py'

# %%
# %cd $main_dir
# !ls
# Out:
# /content/drive/MyDrive/Colab Notebooks/NTC
# Accuracy.png		Flower_FL  __pycache__	     utils.py
# Accuracy_Zoom.png	Loss.png   Result.ipynb
# checkpoint_manager.py	models	   sdn_results
# Federated_Learning_NTC	NTC.ipynb  sdn_saved_models

# %%
# !cp "$checkpoint_py" .
# !cp "$utils_py" .
# !cp "$models_py" .

# %%
from time import time, localtime
import numpy as np
from utils import plot_graph
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler
from keras import losses, metrics, optimizers
import random
import pandas as pd
import sys
import matplotlib.pyplot as plt
import nest_asyncio
from pathlib import Path
from checkpoint_manager import FileCheckpointManager
from keras.models import load_model
import pickle
nest_asyncio.apply()
SEED = 1337
tf.random.set_seed(SEED)

# %%
def train_test_split(df, frac=0.2):
    selected = df['flow_id'].drop_duplicates().sample(frac=frac)
    test = df[df['flow_id'].isin(selected)]
    train = df[~df['flow_id'].isin(selected)]
    return train, test

# %%
from models.CNN_2D import create_keras_model

# %% [markdown]
# Thay đổi các siêu tham số trong cell dưới <br>
# **experiment_name:** Tên bộ dữ liệu được sử dụng, <Tên dữ liệu>_<Số byte sử dụng> <br>
# **method:** Mô hình sử dụng <br>
# **client_lr, server_lr:** Learning rate của client và server, khi fine tune bắt đầu từ 1 và giảm dần xuống 3e-4 <br>
# **NUM_ROUNDS:** Số vòng lặp (Bắt đầu từ 1 và tăng dần lên 3000 nếu mô hình chưa hội tụ - 1/100/200/300/400/500/.../3000) <Br>
# **BATCH_SIZE:** Kích thước batch (Bắt đầu từ 8 và tăng dần lên 64) 8/16/32/64 <br>
# **split:** Để nguyên là 5
# <br>
# **byte_number:** (string): Cac byte cua packet, bao gom 10, 32, 64, 128, 256, 512, 1024, 1460

# %%
byte_number = "128"
experiment_name = "GQUIC_small_" + byte_number
method = "nonFL_VGG19"
client_lr = 3e-4
NUM_ROUNDS = 200
BATCH_SIZE = 32

# %%
this_dir = Path.cwd()
model_dir = this_dir / "sdn_saved_models" / experiment_name / method
output_dir = this_dir / "sdn_results" / experiment_name / method

if not model_dir.exists():
    model_dir.mkdir(parents=True)

if not output_dir.exists():
    output_dir.mkdir(parents=True)

# %%
def sec_to_hours(seconds):
    a = seconds//3600
    b = (seconds % 3600)//60
    c = (seconds % 3600) % 60
    d = "{:.0f} hours {:.0f} mins {:.0f} seconds".format(a, b, c)
    return d

# %%
def most_frequent(List):
    return max(set(List), key=List.count)

# %% [markdown]
# ### **Đọc dữ liệu**

# %%
train_dir = '/content/drive/MyDrive/Colab Notebooks/FL/GQUIC_small/Train/GQUIC_train_' + byte_number + '.feather'
test_dir = '/content/drive/MyDrive/Colab Notebooks/FL/GQUIC_small/Test/GQUIC_test_' + byte_number + '.feather'
data = pd.read_feather(train_dir)
test = pd.read_feather(test_dir)

# %%
data.Label.value_counts() / 20
# Out:
# 4    3742.0
# 0    2842.0
# 2    2808.0
# 1    2034.0
# 3    1740.0
# Name: Label, dtype: float64

# %%
test.Label.value_counts() / 20
# Out:
# 4    903.0
# 0    727.0
# 2    682.0
# 1    522.0
# 3    458.0
# Name: Label, dtype: float64

# %%
data, val = train_test_split(data,frac=0.2)

# %%
result = test.groupby('flow_id')['Label'].apply(list).to_dict()
flow_label = []
for flow in result:
    flow_label.append(most_frequent(result[flow]))

# %%
result = data.groupby('flow_id')['Label'].apply(list).to_dict()
train_label = []
for flow in result:
    train_label.append(most_frequent(result[flow]))

# %%
result = val.groupby('flow_id')['Label'].apply(list).to_dict()
val_label = []
for flow in result:
    val_label.append(most_frequent(result[flow]))

# %%
flow_label = np.array(flow_label)
train_label = np.array(train_label)
val_label = np.array(val_label)

# %%
true_test = test.drop('flow_id', axis=1)
true_data = data.drop('flow_id', axis=1)
true_val = val.drop('flow_id' ,axis=1)

# %%
NUM_FEATURE = len(true_test.columns) - 1
NUM_CLASSES = len(np.unique(true_test['Label']))
print(NUM_FEATURE, NUM_CLASSES)
# Out:
# 128 5

# %%
x_test = true_test.drop('Label', axis=1).to_numpy()/255
x_train = true_data.drop(['Label'], axis=1).to_numpy()/255
x_val = true_val.drop(['Label'],axis=1).to_numpy()/255

# %%
# One flow contains 20 packet
x_train = x_train.reshape(-1,20,NUM_FEATURE)
x_test = x_test.reshape(-1,20,NUM_FEATURE)
x_val = x_val.reshape(-1,20,NUM_FEATURE)

# %%
# x_train = x_train.reshape(-1, 20*NUM_FEATURE)
# x_test = x_test.reshape(-1, 20*NUM_FEATURE)
# x_val = x_val.reshape(-1, 20*NUM_FEATURE)

# %%
print(x_train.shape)
print(x_test.shape)
print(x_val.shape)
# Out:
# (10533, 20, 128)
# (3292, 20, 128)
# (2633, 20, 128)

# %%
import cv2

def _data_processing(x):
  result = []

  for i in range(x.shape[0]):
    tmp = cv2.resize(x[i], (32, 32), interpolation=cv2.INTER_LINEAR)
    result.append(tmp)

  result = np.array(result)
  return result

# %%
x_train = _data_processing(x_train)
x_val = _data_processing(x_val)
x_test = _data_processing(x_test)

# %%
x_train = np.expand_dims(x_train, -1)
x_test  = np.expand_dims(x_test, -1)
x_val = np.expand_dims(x_val, -1)

# %%
print(x_train.shape)
print(x_test.shape)
print(x_val.shape)
# Out:
# (10533, 32, 32, 1)
# (3292, 32, 32, 1)
# (2633, 32, 32, 1)

# %% [markdown]
# ### **Model Definition**

# %%
model = create_keras_model(x_train, NUM_CLASSES)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 20, 128, 32)       832
#
#  conv2d_1 (Conv2D)           (None, 20, 128, 32)       25632
#
#  max_pooling2d (MaxPooling2D  (None, 10, 64, 32)       0
#  )
#
#  dropout (Dropout)           (None, 10, 64, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 10, 64, 64)        18496
#
#  conv2d_3 (Conv2D)           (None, 10, 64, 64)        36928
#
#  max_pooling2d_1 (MaxPooling  (None, 5, 32, 64)        0
#  2D)
#
#  dropout_1 (Dropout)         (None, 5, 32, 64)         0
#
#  flatten (Flatten)           (None, 10240)             0
#
#  dense (Dense)               (None, 256)               2621696
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 5)                 1285
#
# =================================================================
# Total params: 2,704,869
# Trainable params: 2,704,869
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.layers import Input, Concatenate, Dense, Flatten, Dense
from keras.models import Sequential
# from keras.applications.vgg16 import VGG16
# from keras.applications import EfficientNetB0
# from keras.applications import InceptionV3
from keras.applications import VGG19
# from keras.applications import ResNet50

img_input = Input(shape=(32, 32, 1))
img_conc = Concatenate()([img_input, img_input, img_input])

model = Sequential()
conv_base = VGG19(weights=None, include_top=False, input_tensor=img_conc)
model.add(conv_base)
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dense(NUM_CLASSES, activation='softmax'))

model.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg19 (Functional)          (None, 1, 1, 512)         20024384
#
#  flatten_7 (Flatten)         (None, 512)               0
#
#  dense_13 (Dense)            (None, 256)               131328
#
#  dense_14 (Dense)            (None, 5)                 1285
#
# =================================================================
# Total params: 20,156,997
# Trainable params: 20,156,997
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_file = str(model_dir) + '/model.h5'

# %% [markdown]
# ### **Training**

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=client_lr),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(),
    metrics=[tf.keras.metrics.SparseCategoricalAccuracy()]
)

# %%
start = time()
history = model.fit(x_train, train_label, epochs=NUM_ROUNDS, batch_size=BATCH_SIZE, use_multiprocessing=True, shuffle=True, validation_data=(x_val,val_label))
end = time()
duration = end - start
# Out:
# Epoch 1/200
# 330/330 [==============================] - 18s 38ms/step - loss: 1.4391 - sparse_categorical_accuracy: 0.3385 - val_loss: 1.3282 - val_sparse_categorical_accuracy: 0.3790
# Epoch 2/200
# 330/330 [==============================] - 12s 38ms/step - loss: 1.3434 - sparse_categorical_accuracy: 0.3789 - val_loss: 1.3357 - val_sparse_categorical_accuracy: 0.3802
# Epoch 3/200
# 330/330 [==============================] - 13s 39ms/step - loss: 1.3439 - sparse_categorical_accuracy: 0.3777 - val_loss: 1.3292 - val_sparse_categorical_accuracy: 0.3806
# Epoch 4/200
# 330/330 [==============================] - 13s 39ms/step - loss: 1.3404 - sparse_categorical_accuracy: 0.3803 - val_loss: 1.3530 - val_sparse_categorical_accuracy: 0.3802
# Epoch 5/200
# 330/330 [==============================] - 12s 37ms/step - loss: 1.3396 - sparse_categorical_accuracy: 0.3808 - val_loss: 1.3368 - val_sparse_categorical_accuracy: 0.3783
# Epoch 6/200
# 330/330 [==============================] - 13s 39ms/step - loss: 1.3436 - sparse_categorical_accuracy: 0.3794 - val_loss: 1.3293 - val_sparse_categorical_accuracy: 0.3813
# Epoch 7/200
# 330/330 [==============================] - 12s 37ms/step - loss: 1.1476 - sparse_categorical_accuracy: 0.4749 - val_loss: 0.6999 - val_sparse_categorical_accuracy: 0.6931
# Epoch 8/200
# 330/330 [==============================] - 12s 37ms/step - loss: 0.5386 - sparse_categorical_accuracy: 0.7903 - val_loss: 0.5071 - val_sparse_categorical_accuracy: 0.8473
# Epoch 9/200
# 330/330 [==============================] - 13s 39ms/step - loss: 0.3518 - sparse_categorical_accuracy: 0.8780 - val_loss: 0.2760 - val_sparse_categorical_accuracy: 0.9047
# Epoch 10/200
# 330/330 [==============================] - 13s 39ms/step - loss: 0.2870 - sparse_categorical_accuracy: 0.8945 - val_loss: 0.2898 - val_sparse_categorical_accuracy: 0.9047
# Epoch 11/200
# 330/330 [==============================] - 13s 38ms/step - loss: 0.2513 - sparse_categorical_accuracy: 0.9096 - val_loss: 0.2605 - val_sparse_categorical_accuracy: 0.9123
# Epoch 12/200
# 330/330 [==============================] - 13s 38ms/step - loss: 0.2355 - sparse_categorical_accuracy: 0.9160 - val_loss: 0.2255 - val_sparse_categorical_accuracy: 0.9183
# Epoch 13/200
# 330/330 [==============================] - 13s 38ms/step - loss: 0.2187 - sparse_categorical_accuracy: 0.9198 - val_loss: 0.2464 - val_sparse_categorical_accuracy: 0.9161
# Epoch 14/200
# 330/330 [==============================] - 13s 38ms/step - loss: 0.2031 - sparse_categorical_accuracy: 0.9246 - val_loss: 0.2426 - val_sparse_categorical_accuracy: 0.9229
# Epoch 15/200
# 330/330 [==============================] - 13s 38ms/step - loss: 0.2044 - sparse_categorical_accuracy: 0.9258 - val_loss: 0.2494 - val_sparse_categorical_accuracy: 0.9123
# Epoch 16/200
# 330/330 [==============================] - 13s 39ms/step - loss: 0.2034 - sparse_categorical_accuracy: 0.9230 - val_loss: 0.2356 - val_sparse_categorical_accuracy: 0.9142
# Epoch 17/200
# 330/330 [==============================] - 12s 37ms/step - loss: 0.1864 - sparse_categorical_accuracy: 0.9295 - val_loss: 0.2340 - val_sparse_categorical_accuracy: 0.9256
# Epoch 18/200
# 330/330 [==============================] - 12s 37ms/step - loss: 0.2050 - sparse_categorical_accuracy: 0.9229 - val_loss: 0.2421 - val_sparse_categorical_accuracy: 0.9214
# Epoch 19/200
# 330/330 [==============================] - 12s 37ms/step - loss: 0.1598 - sparse_categorical_accuracy: 0.9378 - val_loss: 0.2232 - val_sparse_categorical_accuracy: 0.9252
# Epoch 20/200
# 330/330 [==============================] - 13s 39ms/step - loss: 0.1651 - sparse_categorical_accuracy: 0.9376 - val_loss: 0.2128 - val_sparse_categorical_accuracy: 0.9282
# Epoch 21/200
# 330/330 [==============================] - 12s 37ms/step - loss: 0.1478 - sparse_categorical_accuracy: 0.9432 - val_loss: 0.2331 - val_sparse_categorical_accuracy: 0.9320
# Epoch 22/200
# 330/330 [==============================] - 12s 37ms/step - loss: 0.1500 - sparse_categorical_accuracy: 0.9436 - val_loss: 0.2514 - val_sparse_categorical_accuracy: 0.9267
# Epoch 23/200
# 330/330 [==============================] - 12s 37ms/step - loss: 0.1429 - sparse_categorical_accuracy: 0.9462 - val_loss: 0.2364 - val_sparse_categorical_accuracy: 0.9305
# Epoch 24/200
# 330/330 [==============================] - 12s 37ms/step - loss: 0.1733 - sparse_categorical_accuracy: 0.9371 - val_loss: 0.2668 - val_sparse_categorical_accuracy: 0.9290
# Epoch 25/200
# 330/330 [==============================] - 12s 37ms/step - loss: 0.1349 - sparse_categorical_accuracy: 0.9501 - val_loss: 0.2627 - val_sparse_categorical_accuracy: 0.9290
# Epoch 26/200
# 330/330 [==============================] - 13s 39ms/step - loss: 0.1076 - sparse_categorical_accuracy: 0.9591 - val_loss: 0.2442 - val_sparse_categorical_accuracy: 0.9324
# Epoch 27/200
# 330/330 [==============================] - 13s 39ms/step - loss: 0.1268 - sparse_categorical_accuracy: 0.9554 - val_loss: 0.2643 - val_sparse_categorical_accuracy: 0.9328
# Epoch 28/200
# 330/330 [==============================] - 12s 37ms/step - loss: 0.1985 - sparse_categorical_accuracy: 0.9312 - val_loss: 0.2290 - val_sparse_categorical_accuracy: 0.9290
# Epoch 29/200
# 330/330 [==============================] - 12s 37ms/step - loss: 0.1098 - sparse_categorical_accuracy: 0.9630 - val_loss: 0.2677 - val_sparse_categorical_accuracy: 0.9256
# Epoch 30/200
# 330/330 [==============================] - 13s 39ms/step - loss: 0.0972 - sparse_categorical_accuracy: 0.9673 - val_loss: 0.2160 - val_sparse_categorical_accuracy: 0.9354
# Epoch 31/200
# 330/330 [==============================] - 12s 37ms/step - loss: 0.1241 - sparse_categorical_accuracy: 0.9566 - val_loss: 0.3272 - val_sparse_categorical_accuracy: 0.9354
# Epoch 32/200
# 330/330 [==============================] - 12s 37ms/step - loss: 0.0984 - sparse_categorical_accuracy: 0.9679 - val_loss: 0.3247 - val_sparse_categorical_accuracy: 0.9229
# Epoch 33/200
# 330/330 [==============================] - 12s 37ms/step - loss: 0.0878 - sparse_categorical_accuracy: 0.9723 - val_loss: 0.2913 - val_sparse_categorical_accuracy: 0.9335
# Epoch 34/200
# 330/330 [==============================] - 13s 39ms/step - loss: 0.0847 - sparse_categorical_accuracy: 0.9732 - val_loss: 0.2716 - val_sparse_categorical_accuracy: 0.9221
# Epoch 35/200
# 330/330 [==============================] - 13s 39ms/step - loss: 0.0660 - sparse_categorical_accuracy: 0.9783 - val_loss: 0.3060 - val_sparse_categorical_accuracy: 0.9195
# Epoch 36/200
# 330/330 [==============================] - 12s 37ms/step - loss: 0.0573 - sparse_categorical_accuracy: 0.9822 - val_loss: 0.3962 - val_sparse_categorical_accuracy: 0.9309
# Epoch 37/200
# 330/330 [==============================] - 13s 39ms/step - loss: 0.0780 - sparse_categorical_accuracy: 0.9758 - val_loss: 0.2444 - val_sparse_categorical_accuracy: 0.9335
# Epoch 38/200
# 330/330 [==============================] - 12s 37ms/step - loss: 0.0783 - sparse_categorical_accuracy: 0.9763 - val_loss: 0.3837 - val_sparse_categorical_accuracy: 0.9290
# Epoch 39/200
# 330/330 [==============================] - 13s 39ms/step - loss: 0.0646 - sparse_categorical_accuracy: 0.9806 - val_loss: 0.3292 - val_sparse_categorical_accuracy: 0.9332
# Epoch 40/200
# 330/330 [==============================] - 12s 37ms/step - loss: 0.0596 - sparse_categorical_accuracy: 0.9813 - val_loss: 0.5273 - val_sparse_categorical_accuracy: 0.9305
# Epoch 41/200
# 330/330 [==============================] - 12s 37ms/step - loss: 0.0847 - sparse_categorical_accuracy: 0.9712 - val_loss: 0.4203 - val_sparse_categorical_accuracy: 0.9252
# Epoch 42/200
# 330/330 [==============================] - 12s 37ms/step - loss: 0.0702 - sparse_categorical_accuracy: 0.9780 - val_loss: 0.3010 - val_sparse_categorical_accuracy: 0.9221
# Epoch 43/200
# 330/330 [==============================] - 13s 38ms/step - loss: 0.0513 - sparse_categorical_accuracy: 0.9833 - val_loss: 0.4264 - val_sparse_categorical_accuracy: 0.9286
# Epoch 44/200
# 330/330 [==============================] - 13s 38ms/step - loss: 0.0653 - sparse_categorical_accuracy: 0.9815 - val_loss: 0.3687 - val_sparse_categorical_accuracy: 0.9164
# Epoch 45/200
# 330/330 [==============================] - 12s 37ms/step - loss: 0.0617 - sparse_categorical_accuracy: 0.9822 - val_loss: 0.2998 - val_sparse_categorical_accuracy: 0.9275
# Epoch 46/200
# 330/330 [==============================] - 13s 39ms/step - loss: 0.0350 - sparse_categorical_accuracy: 0.9896 - val_loss: 0.4610 - val_sparse_categorical_accuracy: 0.9320
# Epoch 47/200
# 330/330 [==============================] - 12s 37ms/step - loss: 0.0424 - sparse_categorical_accuracy: 0.9884 - val_loss: 0.3648 - val_sparse_categorical_accuracy: 0.9324
# Epoch 48/200
# 330/330 [==============================] - 13s 39ms/step - loss: 0.0715 - sparse_categorical_accuracy: 0.9807 - val_loss: 0.2533 - val_sparse_categorical_accuracy: 0.9286
# Epoch 49/200
# 330/330 [==============================] - 13s 39ms/step - loss: 0.0430 - sparse_categorical_accuracy: 0.9858 - val_loss: 0.3913 - val_sparse_categorical_accuracy: 0.9267
# Epoch 50/200
# 330/330 [==============================] - 12s 37ms/step - loss: 0.0601 - sparse_categorical_accuracy: 0.9821 - val_loss: 0.3509 - val_sparse_categorical_accuracy: 0.9256
# Epoch 51/200
# 330/330 [==============================] - 13s 39ms/step - loss: 0.0273 - sparse_categorical_accuracy: 0.9911 - val_loss: 0.8048 - val_sparse_categorical_accuracy: 0.9324
# Epoch 52/200
# 330/330 [==============================] - 13s 39ms/step - loss: 0.0371 - sparse_categorical_accuracy: 0.9912 - val_loss: 0.3683 - val_sparse_categorical_accuracy: 0.9278
# Epoch 53/200
# 330/330 [==============================] - 12s 37ms/step - loss: 0.0639 - sparse_categorical_accuracy: 0.9805 - val_loss: 0.3419 - val_sparse_categorical_accuracy: 0.9202
# Epoch 54/200
# 330/330 [==============================] - 12s 37ms/step - loss: 0.0412 - sparse_categorical_accuracy: 0.9872 - val_loss: 0.4897 - val_sparse_categorical_accuracy: 0.9282
# Epoch 55/200
# 330/330 [==============================] - 13s 39ms/step - loss: 0.0345 - sparse_categorical_accuracy: 0.9913 - val_loss: 0.3588 - val_sparse_categorical_accuracy: 0.9252
# Epoch 56/200
# 330/330 [==============================] - 13s 39ms/step - loss: 0.0307 - sparse_categorical_accuracy: 0.9919 - val_loss: 0.5189 - val_sparse_categorical_accuracy: 0.9256
# Epoch 57/200
# 330/330 [==============================] - 13s 39ms/step - loss: 0.0415 - sparse_categorical_accuracy: 0.9890 - val_loss: 0.3787 - val_sparse_categorical_accuracy: 0.9164
# Epoch 58/200
# 330/330 [==============================] - 12s 37ms/step - loss: 0.0658 - sparse_categorical_accuracy: 0.9822 - val_loss: 0.4230 - val_sparse_categorical_accuracy: 0.9278
# Epoch 59/200
# 330/330 [==============================] - 12s 37ms/step - loss: 0.0309 - sparse_categorical_accuracy: 0.9915 - val_loss: 0.4569 - val_sparse_categorical_accuracy: 0.9229
# Epoch 60/200
# 330/330 [==============================] - 13s 39ms/step - loss: 0.0334 - sparse_categorical_accuracy: 0.9902 - val_loss: 0.6182 - val_sparse_categorical_accuracy: 0.9134
# Epoch 61/200
# 330/330 [==============================] - 13s 38ms/step - loss: 0.0505 - sparse_categorical_accuracy: 0.9868 - val_loss: 0.4446 - val_sparse_categorical_accuracy: 0.9199
# Epoch 62/200
# 330/330 [==============================] - 13s 38ms/step - loss: 0.0356 - sparse_categorical_accuracy: 0.9898 - val_loss: 0.4539 - val_sparse_categorical_accuracy: 0.9351
# Epoch 63/200
# 330/330 [==============================] - 12s 37ms/step - loss: 0.0240 - sparse_categorical_accuracy: 0.9937 - val_loss: 0.3348 - val_sparse_categorical_accuracy: 0.9218
# Epoch 64/200
# 330/330 [==============================] - 13s 39ms/step - loss: 0.0263 - sparse_categorical_accuracy: 0.9925 - val_loss: 0.6529 - val_sparse_categorical_accuracy: 0.9233
# Epoch 65/200
# 330/330 [==============================] - 12s 37ms/step - loss: 0.0680 - sparse_categorical_accuracy: 0.9783 - val_loss: 0.6437 - val_sparse_categorical_accuracy: 0.9256
# Epoch 66/200
# 330/330 [==============================] - 12s 37ms/step - loss: 0.0223 - sparse_categorical_accuracy: 0.9928 - val_loss: 0.7523 - val_sparse_categorical_accuracy: 0.9301
# Epoch 67/200
# 330/330 [==============================] - 12s 37ms/step - loss: 0.0296 - sparse_categorical_accuracy: 0.9916 - val_loss: 0.7043 - val_sparse_categorical_accuracy: 0.9320
# Epoch 68/200
# 330/330 [==============================] - 12s 37ms/step - loss: 0.0310 - sparse_categorical_accuracy: 0.9925 - val_loss: 0.5859 - val_sparse_categorical_accuracy: 0.9316
# Epoch 69/200
# 330/330 [==============================] - 13s 39ms/step - loss: 0.0248 - sparse_categorical_accuracy: 0.9927 - val_loss: 0.8345 - val_sparse_categorical_accuracy: 0.9240
# Epoch 70/200
# 330/330 [==============================] - 12s 37ms/step - loss: 0.0806 - sparse_categorical_accuracy: 0.9765 - val_loss: 0.4805 - val_sparse_categorical_accuracy: 0.9229
# Epoch 71/200
# 330/330 [==============================] - 12s 37ms/step - loss: 0.0211 - sparse_categorical_accuracy: 0.9940 - val_loss: 0.7187 - val_sparse_categorical_accuracy: 0.9278
# Epoch 72/200
# 330/330 [==============================] - 12s 37ms/step - loss: 0.0354 - sparse_categorical_accuracy: 0.9901 - val_loss: 0.4404 - val_sparse_categorical_accuracy: 0.9267
# Epoch 73/200
# 330/330 [==============================] - 13s 38ms/step - loss: 0.0414 - sparse_categorical_accuracy: 0.9892 - val_loss: 0.9651 - val_sparse_categorical_accuracy: 0.9218
# Epoch 74/200
# 330/330 [==============================] - 12s 37ms/step - loss: 0.0342 - sparse_categorical_accuracy: 0.9900 - val_loss: 0.9040 - val_sparse_categorical_accuracy: 0.9294
# Epoch 75/200
# 330/330 [==============================] - 13s 39ms/step - loss: 0.0403 - sparse_categorical_accuracy: 0.9902 - val_loss: 0.4397 - val_sparse_categorical_accuracy: 0.9187
# Epoch 76/200
# 330/330 [==============================] - 13s 38ms/step - loss: 0.0371 - sparse_categorical_accuracy: 0.9882 - val_loss: 0.5240 - val_sparse_categorical_accuracy: 0.9294
# Epoch 77/200
# 330/330 [==============================] - 12s 37ms/step - loss: 0.0132 - sparse_categorical_accuracy: 0.9968 - val_loss: 0.6726 - val_sparse_categorical_accuracy: 0.9320
# Epoch 78/200
# 330/330 [==============================] - 13s 39ms/step - loss: 0.0432 - sparse_categorical_accuracy: 0.9899 - val_loss: 0.4829 - val_sparse_categorical_accuracy: 0.9324
# Epoch 79/200
# 330/330 [==============================] - 12s 37ms/step - loss: 0.0170 - sparse_categorical_accuracy: 0.9953 - val_loss: 0.7874 - val_sparse_categorical_accuracy: 0.9244
# Epoch 80/200
# 330/330 [==============================] - 13s 39ms/step - loss: 0.0277 - sparse_categorical_accuracy: 0.9926 - val_loss: 0.7189 - val_sparse_categorical_accuracy: 0.9343
# Epoch 81/200
# 330/330 [==============================] - 12s 37ms/step - loss: 0.0242 - sparse_categorical_accuracy: 0.9938 - val_loss: 0.4028 - val_sparse_categorical_accuracy: 0.9278
# Epoch 82/200
# 330/330 [==============================] - 12s 37ms/step - loss: 0.0139 - sparse_categorical_accuracy: 0.9964 - val_loss: 0.7488 - val_sparse_categorical_accuracy: 0.9313
# Epoch 83/200
# 330/330 [==============================] - 13s 39ms/step - loss: 0.0506 - sparse_categorical_accuracy: 0.9875 - val_loss: 0.6594 - val_sparse_categorical_accuracy: 0.9256
# Epoch 84/200
# 330/330 [==============================] - 13s 39ms/step - loss: 0.0327 - sparse_categorical_accuracy: 0.9916 - val_loss: 0.6069 - val_sparse_categorical_accuracy: 0.9229
# Epoch 85/200
# 330/330 [==============================] - 13s 39ms/step - loss: 0.0541 - sparse_categorical_accuracy: 0.9835 - val_loss: 0.4233 - val_sparse_categorical_accuracy: 0.9286
# Epoch 86/200
# 330/330 [==============================] - 13s 39ms/step - loss: 0.0244 - sparse_categorical_accuracy: 0.9928 - val_loss: 0.5507 - val_sparse_categorical_accuracy: 0.9290
# Epoch 87/200
# 330/330 [==============================] - 12s 37ms/step - loss: 0.0156 - sparse_categorical_accuracy: 0.9953 - val_loss: 0.8146 - val_sparse_categorical_accuracy: 0.9275
# Epoch 88/200
# 330/330 [==============================] - 13s 39ms/step - loss: 0.0505 - sparse_categorical_accuracy: 0.9896 - val_loss: 0.5147 - val_sparse_categorical_accuracy: 0.9271
# Epoch 89/200
# 330/330 [==============================] - 12s 37ms/step - loss: 0.0184 - sparse_categorical_accuracy: 0.9942 - val_loss: 0.5830 - val_sparse_categorical_accuracy: 0.9297
# Epoch 90/200
# 330/330 [==============================] - 13s 39ms/step - loss: 0.0501 - sparse_categorical_accuracy: 0.9861 - val_loss: 0.8932 - val_sparse_categorical_accuracy: 0.9286
# Epoch 91/200
# 330/330 [==============================] - 13s 38ms/step - loss: 0.0293 - sparse_categorical_accuracy: 0.9918 - val_loss: 0.3832 - val_sparse_categorical_accuracy: 0.9035
# Epoch 92/200
# 330/330 [==============================] - 13s 38ms/step - loss: 0.0666 - sparse_categorical_accuracy: 0.9800 - val_loss: 0.4444 - val_sparse_categorical_accuracy: 0.9286
# Epoch 93/200
# 330/330 [==============================] - 13s 39ms/step - loss: 0.0138 - sparse_categorical_accuracy: 0.9961 - val_loss: 0.6136 - val_sparse_categorical_accuracy: 0.9263
# Epoch 94/200
# 330/330 [==============================] - 13s 39ms/step - loss: 0.0107 - sparse_categorical_accuracy: 0.9968 - val_loss: 0.7811 - val_sparse_categorical_accuracy: 0.9278
# Epoch 95/200
# 330/330 [==============================] - 13s 39ms/step - loss: 0.0045 - sparse_categorical_accuracy: 0.9988 - val_loss: 0.8769 - val_sparse_categorical_accuracy: 0.9256
# Epoch 96/200
# 330/330 [==============================] - 13s 39ms/step - loss: 0.0038 - sparse_categorical_accuracy: 0.9989 - val_loss: 1.2125 - val_sparse_categorical_accuracy: 0.9301
# Epoch 97/200
# 330/330 [==============================] - 12s 38ms/step - loss: 0.0037 - sparse_categorical_accuracy: 0.9990 - val_loss: 1.3057 - val_sparse_categorical_accuracy: 0.9309
# Epoch 98/200
# 330/330 [==============================] - 13s 39ms/step - loss: 0.0035 - sparse_categorical_accuracy: 0.9990 - val_loss: 1.3766 - val_sparse_categorical_accuracy: 0.9301
# Epoch 99/200
# 330/330 [==============================] - 13s 39ms/step - loss: 0.0036 - sparse_categorical_accuracy: 0.9990 - val_loss: 1.4677 - val_sparse_categorical_accuracy: 0.9305
# Epoch 100/200
# 330/330 [==============================] - 13s 39ms/step - loss: 0.0041 - sparse_categorical_accuracy: 0.9989 - val_loss: 1.4813 - val_sparse_categorical_accuracy: 0.9305
# Epoch 101/200
# 330/330 [==============================] - 13s 39ms/step - loss: 0.0036 - sparse_categorical_accuracy: 0.9990 - val_loss: 1.7622 - val_sparse_categorical_accuracy: 0.9290
# Epoch 102/200
# 330/330 [==============================] - 12s 37ms/step - loss: 0.0036 - sparse_categorical_accuracy: 0.9990 - val_loss: 1.8441 - val_sparse_categorical_accuracy: 0.9294
# Epoch 103/200
# 330/330 [==============================] - 13s 39ms/step - loss: 0.0037 - sparse_categorical_accuracy: 0.9990 - val_loss: 1.8694 - val_sparse_categorical_accuracy: 0.9301
# Epoch 104/200
# 330/330 [==============================] - 13s 39ms/step - loss: 0.0034 - sparse_categorical_accuracy: 0.9990 - val_loss: 2.0855 - val_sparse_categorical_accuracy: 0.9294
# Epoch 105/200
# 330/330 [==============================] - 12s 37ms/step - loss: 0.0965 - sparse_categorical_accuracy: 0.9735 - val_loss: 0.4154 - val_sparse_categorical_accuracy: 0.9313
# Epoch 106/200
# 330/330 [==============================] - 12s 37ms/step - loss: 0.0762 - sparse_categorical_accuracy: 0.9792 - val_loss: 0.4137 - val_sparse_categorical_accuracy: 0.9320
# Epoch 107/200
# 330/330 [==============================] - 13s 39ms/step - loss: 0.0246 - sparse_categorical_accuracy: 0.9934 - val_loss: 0.3544 - val_sparse_categorical_accuracy: 0.9153
# Epoch 108/200
# 330/330 [==============================] - 12s 37ms/step - loss: 0.0936 - sparse_categorical_accuracy: 0.9794 - val_loss: 0.4142 - val_sparse_categorical_accuracy: 0.9282
# Epoch 109/200
# 330/330 [==============================] - 13s 39ms/step - loss: 0.0151 - sparse_categorical_accuracy: 0.9955 - val_loss: 0.6904 - val_sparse_categorical_accuracy: 0.9297
# Epoch 110/200
# 330/330 [==============================] - 13s 39ms/step - loss: 0.0139 - sparse_categorical_accuracy: 0.9954 - val_loss: 0.6154 - val_sparse_categorical_accuracy: 0.9275
# Epoch 111/200
# 330/330 [==============================] - 13s 39ms/step - loss: 0.0276 - sparse_categorical_accuracy: 0.9933 - val_loss: 0.5299 - val_sparse_categorical_accuracy: 0.9286
# Epoch 112/200
# 330/330 [==============================] - 12s 37ms/step - loss: 0.0217 - sparse_categorical_accuracy: 0.9939 - val_loss: 0.7828 - val_sparse_categorical_accuracy: 0.9305
# Epoch 113/200
# 330/330 [==============================] - 13s 39ms/step - loss: 0.0186 - sparse_categorical_accuracy: 0.9954 - val_loss: 0.5779 - val_sparse_categorical_accuracy: 0.9313
# Epoch 114/200
# 330/330 [==============================] - 12s 37ms/step - loss: 0.0151 - sparse_categorical_accuracy: 0.9967 - val_loss: 0.6215 - val_sparse_categorical_accuracy: 0.9237
# Epoch 115/200
# 330/330 [==============================] - 13s 39ms/step - loss: 0.0428 - sparse_categorical_accuracy: 0.9909 - val_loss: 0.4316 - val_sparse_categorical_accuracy: 0.9305
# Epoch 116/200
# 330/330 [==============================] - 13s 39ms/step - loss: 0.0162 - sparse_categorical_accuracy: 0.9951 - val_loss: 0.6018 - val_sparse_categorical_accuracy: 0.9256
# Epoch 117/200
# 330/330 [==============================] - 12s 37ms/step - loss: 0.0186 - sparse_categorical_accuracy: 0.9953 - val_loss: 0.6370 - val_sparse_categorical_accuracy: 0.9309
# Epoch 118/200
# 330/330 [==============================] - 12s 37ms/step - loss: 0.0073 - sparse_categorical_accuracy: 0.9978 - val_loss: 1.6131 - val_sparse_categorical_accuracy: 0.9282
# Epoch 119/200
# 330/330 [==============================] - 13s 39ms/step - loss: 0.0226 - sparse_categorical_accuracy: 0.9934 - val_loss: 0.8740 - val_sparse_categorical_accuracy: 0.9366
# Epoch 120/200
# 330/330 [==============================] - 13s 39ms/step - loss: 0.0160 - sparse_categorical_accuracy: 0.9962 - val_loss: 0.5530 - val_sparse_categorical_accuracy: 0.9240
# Epoch 121/200
# 330/330 [==============================] - 13s 39ms/step - loss: 0.0246 - sparse_categorical_accuracy: 0.9932 - val_loss: 0.3686 - val_sparse_categorical_accuracy: 0.9278
# Epoch 122/200
# 330/330 [==============================] - 12s 37ms/step - loss: 0.0125 - sparse_categorical_accuracy: 0.9964 - val_loss: 0.5120 - val_sparse_categorical_accuracy: 0.9149
# Epoch 123/200
# 330/330 [==============================] - 13s 39ms/step - loss: 0.0277 - sparse_categorical_accuracy: 0.9923 - val_loss: 1.0706 - val_sparse_categorical_accuracy: 0.9275
# Epoch 124/200
# 330/330 [==============================] - 12s 37ms/step - loss: 0.0258 - sparse_categorical_accuracy: 0.9923 - val_loss: 0.6531 - val_sparse_categorical_accuracy: 0.9290
# Epoch 125/200
# 330/330 [==============================] - 12s 37ms/step - loss: 0.0166 - sparse_categorical_accuracy: 0.9958 - val_loss: 0.8250 - val_sparse_categorical_accuracy: 0.9301
# Epoch 126/200
# 330/330 [==============================] - 13s 39ms/step - loss: 0.0088 - sparse_categorical_accuracy: 0.9970 - val_loss: 0.9190 - val_sparse_categorical_accuracy: 0.9347
# Epoch 127/200
# 330/330 [==============================] - 13s 38ms/step - loss: 0.0043 - sparse_categorical_accuracy: 0.9988 - val_loss: 1.2136 - val_sparse_categorical_accuracy: 0.9335
# Epoch 128/200
# 330/330 [==============================] - 12s 37ms/step - loss: 0.0035 - sparse_categorical_accuracy: 0.9990 - val_loss: 1.4888 - val_sparse_categorical_accuracy: 0.9351
# Epoch 129/200
# 330/330 [==============================] - 13s 39ms/step - loss: 0.0037 - sparse_categorical_accuracy: 0.9990 - val_loss: 1.5928 - val_sparse_categorical_accuracy: 0.9351
# Epoch 130/200
# 330/330 [==============================] - 13s 39ms/step - loss: 0.0036 - sparse_categorical_accuracy: 0.9990 - val_loss: 1.6851 - val_sparse_categorical_accuracy: 0.9347
# Epoch 131/200
# 330/330 [==============================] - 13s 39ms/step - loss: 0.0037 - sparse_categorical_accuracy: 0.9990 - val_loss: 1.7514 - val_sparse_categorical_accuracy: 0.9339
# Epoch 132/200
# 330/330 [==============================] - 13s 39ms/step - loss: 0.0036 - sparse_categorical_accuracy: 0.9990 - val_loss: 1.8593 - val_sparse_categorical_accuracy: 0.9343
# Epoch 133/200
# 330/330 [==============================] - 13s 39ms/step - loss: 0.0035 - sparse_categorical_accuracy: 0.9990 - val_loss: 2.0155 - val_sparse_categorical_accuracy: 0.9351
# Epoch 134/200
# 330/330 [==============================] - 12s 38ms/step - loss: 0.0034 - sparse_categorical_accuracy: 0.9990 - val_loss: 2.2084 - val_sparse_categorical_accuracy: 0.9339
# Epoch 135/200
# 330/330 [==============================] - 13s 39ms/step - loss: 0.0035 - sparse_categorical_accuracy: 0.9990 - val_loss: 2.1224 - val_sparse_categorical_accuracy: 0.9358
# Epoch 136/200
# 330/330 [==============================] - 13s 39ms/step - loss: 0.0036 - sparse_categorical_accuracy: 0.9990 - val_loss: 2.1978 - val_sparse_categorical_accuracy: 0.9351
# Epoch 137/200
# 330/330 [==============================] - 13s 39ms/step - loss: 0.0036 - sparse_categorical_accuracy: 0.9990 - val_loss: 2.2482 - val_sparse_categorical_accuracy: 0.9343
# Epoch 138/200
# 330/330 [==============================] - 12s 38ms/step - loss: 0.0036 - sparse_categorical_accuracy: 0.9990 - val_loss: 2.3146 - val_sparse_categorical_accuracy: 0.9343
# Epoch 139/200
# 330/330 [==============================] - 13s 39ms/step - loss: 0.0036 - sparse_categorical_accuracy: 0.9990 - val_loss: 2.3425 - val_sparse_categorical_accuracy: 0.9335
# Epoch 140/200
# 330/330 [==============================] - 12s 37ms/step - loss: 0.0036 - sparse_categorical_accuracy: 0.9990 - val_loss: 2.3916 - val_sparse_categorical_accuracy: 0.9343
# Epoch 141/200
# 330/330 [==============================] - 12s 37ms/step - loss: 0.0035 - sparse_categorical_accuracy: 0.9990 - val_loss: 2.3953 - val_sparse_categorical_accuracy: 0.9343
# Epoch 142/200
# 330/330 [==============================] - 13s 39ms/step - loss: 0.0037 - sparse_categorical_accuracy: 0.9990 - val_loss: 2.4439 - val_sparse_categorical_accuracy: 0.9339
# Epoch 143/200
# 330/330 [==============================] - 12s 37ms/step - loss: 0.0035 - sparse_categorical_accuracy: 0.9990 - val_loss: 2.4582 - val_sparse_categorical_accuracy: 0.9328
# Epoch 144/200
# 330/330 [==============================] - 13s 38ms/step - loss: 0.0036 - sparse_categorical_accuracy: 0.9990 - val_loss: 2.4757 - val_sparse_categorical_accuracy: 0.9347
# Epoch 145/200
# 330/330 [==============================] - 13s 39ms/step - loss: 0.0036 - sparse_categorical_accuracy: 0.9990 - val_loss: 2.5441 - val_sparse_categorical_accuracy: 0.9339
# Epoch 146/200
# 330/330 [==============================] - 13s 39ms/step - loss: 0.0035 - sparse_categorical_accuracy: 0.9990 - val_loss: 2.6517 - val_sparse_categorical_accuracy: 0.9339
# Epoch 147/200
# 330/330 [==============================] - 13s 38ms/step - loss: 0.0035 - sparse_categorical_accuracy: 0.9990 - val_loss: 2.6510 - val_sparse_categorical_accuracy: 0.9339
# Epoch 148/200
# 330/330 [==============================] - 13s 38ms/step - loss: 0.0034 - sparse_categorical_accuracy: 0.9990 - val_loss: 2.8235 - val_sparse_categorical_accuracy: 0.9335
# Epoch 149/200
#  45/330 [===>..........................] - ETA: 10s - loss: 0.0046 - sparse_categorical_accuracy: 0.9986

# %%
model.save(model_file)

# %%
# Lưu lại history vào file
with open(history_file, 'wb') as f:
    pickle.dump(history.history, f)

# %%
total_time = "Time: {}".format(sec_to_hours(duration))
print(total_time)

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))

# %% [markdown]
# ### **Evaluation**

# %%
best_model_accuracy = history.history['sparse_categorical_accuracy'][np.argmin(history.history['loss'])]

# %%
test_acc = model.evaluate(x_test, flow_label, verbose=2, batch_size=BATCH_SIZE, use_multiprocessing=True)

# %%
train_val = str(best_model_accuracy*100) + "_" + str(test_acc[1]*100)

# %%
print(train_val)

# %%
with open(output_dir/'parameters.txt', 'w') as f:
    print('client_lr: {}\nEpochs: {}\nBATCH_SIZE: {}'.format(
        client_lr, NUM_ROUNDS, BATCH_SIZE), file=f)
    f.close()

# %%
with open(output_dir/'time.txt', 'w') as f:
    print(total_time, file=f)
    f.close()

# %%
predictions = model.predict(x_test, verbose=2, use_multiprocessing=True, batch_size=BATCH_SIZE)

# %%
flow_pred = np.argmax(predictions, axis=-1)

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import classification_report

classes = []
for c in range(NUM_CLASSES):
    classes.append("Class {}".format(c))
print(classes)
with open(output_dir/'metrics.txt', 'w') as f:
    confusion = confusion_matrix(flow_label, flow_pred)
    print('Confusion Matrix\n', file=f)
    print(confusion, file=f)

    # importing accuracy_score, precision_score, recall_score, f1_score
    print('\nAccuracy: {:.2f}\n'.format(
        accuracy_score(flow_label, flow_pred)), file=f)

    print('Micro Precision: {:.2f}\n'.format(
        precision_score(flow_label, flow_pred, average='micro')), file=f)
    print('Micro Recall: {:.2f}\n'.format(
        recall_score(flow_label, flow_pred, average='micro')), file=f)
    print(
        'Micro F1-score: {:.2f}\n'.format(f1_score(flow_label, flow_pred, average='micro')), file=f)

    print('Macro Precision: {:.2f}\n'.format(
        precision_score(flow_label, flow_pred, average='macro')), file=f)
    print('Macro Recall: {:.2f}\n'.format(
        recall_score(flow_label, flow_pred, average='macro')), file=f)
    print(
        'Macro F1-score: {:.2f}\n'.format(f1_score(flow_label, flow_pred, average='macro')), file=f)

    print('Weighted Precision: {:.2f}\n'.format(
        precision_score(flow_label, flow_pred, average='weighted')), file=f)
    print('Weighted Recall: {:.2f}\n'.format(
        recall_score(flow_label, flow_pred, average='weighted')), file=f)
    print(
        'Weighted F1-score: {:.2f}\n'.format(f1_score(flow_label, flow_pred, average='weighted')), file=f)

    print('\nClassification Report\n', file=f)
    print(classification_report(flow_label, flow_pred, target_names=classes), file=f)
    f.close()

# %%
epochs = range(1, len(history.history['sparse_categorical_accuracy']) + 1)

fig = plt.figure(figsize=(10, 6))
plt.plot(epochs, history.history['sparse_categorical_accuracy'], label='accuracy')
plt.plot(epochs, history.history['val_sparse_categorical_accuracy'], label='val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0,1])
plt.title('Training and validation accuracy')
plt.legend()
plt.savefig(output_dir / "normal_model_Accuracy.png")

# %%
fig = plt.figure(figsize=(10, 6))
plt.plot(epochs, history.history['loss'], label='loss')
plt.plot(epochs, history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and validation loss')
plt.legend()
plt.savefig(output_dir / "normal_model_Loss.png")
